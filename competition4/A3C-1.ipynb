# %%
from ple.games.flappybird import FlappyBird
from ple import PLE
import matplotlib.pyplot as plt
import os
import numpy as np

# %matplotlib inline
os.environ["SDL_VIDEODRIVER"] = "dummy"  # this line disable pop-out window
game = FlappyBird()
env = PLE(game, fps=30, display_screen=False)  # environment interface to game
env.reset_game()
# return a dictionary whose key is action description and value is action index
print(game.actions)
# return a list of action index (include None)
print(env.getActionSet())
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom
# {'up': 119}
# [119, None]

# %%
# a dictionary describe state
'''
    player y position.
    players velocity.
    next pipe distance to player
    next pipe top y position
    next pipe bottom y position
    next next pipe distance to player
    next next pipe top y position
    next next pipe bottom y position
'''
game.getGameState()
# Out:
# {'player_y': 256,
#  'player_vel': 0,
#  'next_pipe_dist_to_player': 309.0,
#  'next_pipe_top_y': 144,
#  'next_pipe_bottom_y': 244,
#  'next_next_pipe_dist_to_player': 453.0,
#  'next_next_pipe_top_y': 160,
#  'next_next_pipe_bottom_y': 260}

# %%
num_action = len(env.getActionSet())
bucket_range_per_feature = {
  'next_next_pipe_bottom_y': 40,
  'next_next_pipe_dist_to_player': 512,
  'next_next_pipe_top_y': 40,
  'next_pipe_bottom_y': 20,
  'next_pipe_dist_to_player': 20,
  'next_pipe_top_y': 20,
  'player_vel': 4,
  'player_y': 16
}
# init agent
# agent = Agent(bucket_range_per_feature, num_action)

# %%
import multiprocessing
import threading

# %%
multiprocessing.cpu_count()
# Out:
# 12

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
class ActorCriticModel(keras.Model):
    def __init__(self, state_size, action_size):
        super(ActorCriticModel, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.dense1 = layers.Dense(256, activation='relu')
        self.policy_logits = layers.Dense(action_size)
        self.dense2 = layers.Dense(256, activation='relu')
        self.values = layers.Dense(1)

    def call(self, inputs):
        # Forward pass
        x = self.dense1(inputs)
        logits = self.policy_logits(x)
        v1 = self.dense2(inputs)
        values = self.values(v1)
        return logits, values

# %%
# import skimage.transform
import moviepy.editor as mpy
import copy
def preprocess_state(state):
    
    # return  np.expand_dims(np.array(list(state.values()), dtype=np.float32), axis=-1)
    return TA_state(state)

def TA_state(state):
    
    state['next_next_pipe_bottom_y'] -= state['player_y']
    state['next_next_pipe_top_y'] -= state['player_y']
    state['next_pipe_bottom_y'] -= state['player_y']
    state['next_pipe_top_y'] -= state['player_y']
    relative_state = list(state.values())


    # return the state in tensor type, with batch dimension
    relative_state = tf.convert_to_tensor(relative_state, dtype=tf.float32)
    relative_state = tf.expand_dims(relative_state, axis=0)
    
    return relative_state

def record(episode,
           episode_reward,
           worker_idx,
           global_ep_reward,
           result_queue,
           total_loss,
           num_steps):
    """Helper function to store score and print statistics.
    Args:
    episode: Current episode
    episode_reward: Reward accumulated over the current episode
    worker_idx: Which thread (worker)
    global_ep_reward: The moving average of the global reward
    result_queue: Queue storing the moving average of the scores
    total_loss: The total loss accumualted over the current episode
    num_steps: The number of steps the episode took to complete
    """
    if global_ep_reward == 0:
        global_ep_reward = episode_reward
    else:
        global_ep_reward = global_ep_reward * 0.99 + episode_reward * 0.01
    print(
      f"Episode: {episode} | "
      f"Moving Average Reward: {global_ep_reward:0.2f} | "
      f"Episode Reward: {episode_reward:0.2f} | "
      f"True Reward: {(episode_reward - num_steps*0.1):0.2f} |"
      f"Loss: {int(total_loss / float(num_steps) * 1000) / 1000} | "
      f"Steps: {num_steps} | "
      f"Worker: {worker_idx}"
      )
    result_queue.put(global_ep_reward)
    return global_ep_reward


def make_anim(images, fps=60, true_image=False):
    duration = len(images) / fps

    def make_frame(t):
        try:
            x = images[int(len(images) / duration * t)]
        except:
            x = images[-1]

        if true_image:
            return x.astype(np.uint8)
        else:
            return ((x + 1) / 2 * 255).astype(np.uint8)

    clip = mpy.VideoClip(make_frame, duration=duration)
    clip.fps = fps
    return clip

# %%
preprocess_state(env.getGameState())
# Out:
# <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
# array([[ 256.,    0.,  309., -112.,  -12.,  453.,  -96.,    4.]],
#       dtype=float32)>

# %%
from queue import Queue
class MasterAgent():
    def __init__(self, start_from_old=False, model_name=None):
        self.game_name = 'FlappyBird'
        save_dir = SAVE_DIR
        self.save_dir = save_dir
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        game = FlappyBird()
        env = PLE(game, fps=30, display_screen=False)
        self.state_size = len(game.getGameState())
        self.action_size = len(env.getActionSet())
        self.opt = tf.compat.v1.train.AdamOptimizer(LR, use_locking=True)
        print(self.state_size, self.action_size)

        self.global_model = ActorCriticModel(self.state_size, self.action_size)  # global network
        self.global_model(tf.convert_to_tensor(np.random.random((1, self.state_size)), dtype=tf.float32))
        if start_from_old:
            model_path = os.path.join(self.save_dir, 'model_{}_final.h5'.format(self.game_name))
            if model_name:
                model_path = os.path.join(self.save_dir, model_name)
            print('Loading model from: {}'.format(model_path))
            self.global_model.load_weights(model_path)
        
    def train(self):
        res_queue = Queue()

        workers = [Worker(self.state_size,
                          self.action_size,
                          self.global_model,
                          self.opt, res_queue,
                          i, game_name=self.game_name,
                          save_dir=self.save_dir) for i in range(multiprocessing.cpu_count())]

        for i, worker in enumerate(workers):
            print("Starting worker {}".format(i))
            worker.start()

        moving_average_rewards = []  # record episode reward to plot
        while True:
            reward = res_queue.get()
            if reward is not None:
                moving_average_rewards.append(reward)
            else:
                break
            
            if Worker.global_episode % 500 == 0:
                with Worker.save_lock:
                    print("Saving checkpoint model to {}, "
                          "episode score: {}".format(self.save_dir, reward))
                    self.global_model.save_weights(
                        os.path.join(self.save_dir,
                        'model_{}.h5'.format(self.game_name))
                    )
        [w.join() for w in workers]

        self.global_model.save_weights(
            os.path.join(self.save_dir,
            'model_{}_final.h5'.format(self.game_name))
        )
        
        plt.plot(moving_average_rewards)
        plt.ylabel('Moving average ep reward')
        plt.xlabel('Step')
        plt.savefig(os.path.join(self.save_dir,
                                 '{} Moving Average.png'.format(self.game_name)))
        plt.show()
        
    def play(self):
        game = FlappyBird(pipe_gap=PIPE_GAP)
        env = PLE(game, fps=30, display_screen=False)
        env.reset_game()
        state = preprocess_state(game.getGameState())
        model = self.global_model
        model_path = os.path.join(self.save_dir, 'model_{}.h5'.format(self.game_name))
        print('Loading model from: {}'.format(model_path))
        model.load_weights(model_path)
        done = False
        step_counter = 0
        reward_sum = 0

        frames = []
        
        try:
            while not done and step_counter < 1000:
                frames.append(env.getScreenRGB())
                policy, value = model(state)
                policy = tf.nn.softmax(policy)
                action = np.argmax(policy)
                
                reward = env.act(env.getActionSet()[action])
                state = preprocess_state(game.getGameState())
                done = env.game_over()
                
                reward_sum += reward
                print(f"{step_counter}. Reward: {reward_sum}, action: {action}, policy: {policy}")
                step_counter += 1
        except KeyboardInterrupt:
              print("Received Keyboard Interrupt. Shutting down.")
        clip = make_anim(frames, fps=60, true_image=True).rotate(-90)
        # clip.write_videofile("movie_f/DQN_demo-{}.webm".format(episode), fps=60)
        display(clip.ipython_display(fps=60, autoplay=1, loop=1, maxduration=120))

# %%
class Memory:
    def __init__(self):
        self.states = []
        self.actions = []
        self.rewards = []
    
    def store(self, state, action, reward):
        self.states.append(state)
        self.actions.append(action)
        self.rewards.append(reward)
    
    def clear(self):
        self.states = []
        self.actions = []
        self.rewards = []

# %%
MAX_EPS = 1000
PIPE_GAP = 100
UPDATE_FREQ = 25
SAVE_DIR = './gap_change'
LR = 1e-5
GAMMA = 0.99

# %%
import matplotlib.pyplot as plt
from PIL import Image
class Worker(threading.Thread):
    # Set up global variables across different threads
    global_episode = 0
    # Moving average reward
    global_moving_average_reward = 0
    best_score = 0
    save_lock = threading.Lock()

    def __init__(self,
               state_size,
               action_size,
               global_model,
               opt,
               result_queue,
               idx,
               game_name='FlappyBird',
               save_dir='/tmp'):
        super(Worker, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.result_queue = result_queue
        self.global_model = global_model
        self.opt = opt
        self.local_model = ActorCriticModel(self.state_size, self.action_size)
        self.worker_idx = idx
        self.game_name = game_name
        self.game = FlappyBird(pipe_gap=PIPE_GAP)
        self.env = PLE(self.game, fps=30, display_screen=False)
        self.save_dir = save_dir
        self.ep_loss = 0.0
        
    
    def run(self):
        total_step = 1
        mem = Memory()
        while Worker.global_episode < MAX_EPS:
            self.env.reset_game()
            current_state = preprocess_state(self.game.getGameState())
            mem.clear()
            ep_reward = 0.
            ep_steps = 0
            self.ep_loss = 0

            time_count = 0
            done = False

            while not done:
                # plt.imshow(Image.fromarray(self.env.getScreenRGB()))
                # plt.show()
                logits, _ = self.local_model(current_state)
                probs = tf.nn.softmax(logits)
                # print(probs)
                action = np.random.choice(self.action_size, p=probs.numpy()[0])
                
                # print(time_count, current_state,  action)
                
                reward = self.env.act(self.env.getActionSet()[action])
                new_state = preprocess_state(self.game.getGameState())
                done = self.env.game_over()
                # new_state, reward, done, _ = self.env.act(self.env.getActionSet()[action])
                # if done:
                #     reward = -5
                if not done:
                    alive_bouns = 0.1
                else:
                    alive_bouns = 0.0
                ep_reward += reward + alive_bouns
                mem.store(current_state, action, reward)

                if time_count == UPDATE_FREQ or done:
                  # Calculate gradient wrt to local model. We do so by tracking the
                  # variables involved in computing the loss by using tf.GradientTape
                    with tf.GradientTape() as tape:
                        total_loss = self.compute_loss(done,
                                                   new_state,
                                                   mem,
                                                   GAMMA)
                    self.ep_loss += total_loss
                    # Calculate local gradients
                    grads = tape.gradient(total_loss, self.local_model.trainable_weights)
                    # Push local gradients to global model
                    self.opt.apply_gradients(zip(grads,
                                               self.global_model.trainable_weights))
                    # Update local model with new weights
                    self.local_model.set_weights(self.global_model.get_weights())

                    mem.clear()
                    time_count = 0

                    if done:  # done and print information
                        Worker.global_moving_average_reward = \
                        record(Worker.global_episode, ep_reward, self.worker_idx,
                             Worker.global_moving_average_reward, self.result_queue,
                             self.ep_loss, ep_steps)
                        # We must use a lock to save our model and to print to prevent data races.
                        if ep_reward > Worker.best_score:
                            with Worker.save_lock:
                                print("Saving best model to {}, "
                                      "episode score: {}".format(self.save_dir, ep_reward))
                                self.global_model.save_weights(
                                    os.path.join(self.save_dir,
                                    'model_{}.h5'.format(self.game_name))
                                )
                                Worker.best_score = ep_reward
                        Worker.global_episode += 1
                ep_steps += 1

                time_count += 1
                current_state = new_state
                total_step += 1
        self.result_queue.put(None)
    def compute_loss(self,
                   done,
                   new_state,
                   memory,
                   gamma=0.99):
        # print(new_state, done)
        if done:
            reward_sum = 0.  # terminal
        else:
            _, reward_sum = self.local_model(
                tf.convert_to_tensor([new_state],
                                     dtype=tf.float32))
            # reward_sum = reward_sum.numpy()[0]
        # print(reward_sum)
        # Get discounted rewards
        discounted_rewards = []
        for reward in memory.rewards[::-1]:  # reverse buffer r
            reward_sum = reward + gamma * reward_sum
            discounted_rewards.append(reward_sum)
        discounted_rewards.reverse()

        logits, values = self.local_model(
            tf.convert_to_tensor(np.vstack(memory.states),
                                 dtype=tf.float32))
        # Get our advantages
        advantage = tf.convert_to_tensor(np.array(discounted_rewards)[:, None],
                                dtype=tf.float32) - values
        # Value loss
        value_loss = advantage ** 2

        # Calculate our policy loss
        actions_one_hot = tf.one_hot(memory.actions, self.action_size, dtype=tf.float32)

        policy = tf.nn.softmax(logits)
        entropy = tf.reduce_sum(policy * tf.math.log(policy + 1e-20), axis=1)

        policy_loss = tf.compat.v1.nn.softmax_cross_entropy_with_logits_v2(labels=actions_one_hot,
                                                                 logits=logits)
        policy_loss *= tf.stop_gradient(advantage)
        policy_loss -= 0.01 * entropy
        total_loss = tf.reduce_mean((0.5 * value_loss + policy_loss))
        return total_loss

# %%
test_global_model = ActorCriticModel(8, 2)  # global network
# test_global_model(tf.convert_to_tensor(np.random.random((1, 8)), dtype=tf.float32))
optimizer = tf.compat.v1.train.AdamOptimizer(LR, use_locking=True)
q = Queue()
test_worker = Worker(8,
                     2,
                     test_global_model,
                     optimizer, q,
                     0, game_name='FlappyBird',
                      save_dir=SAVE_DIR)

# %%
Worker.global_episode = 0

# %%
master = MasterAgent(True, model_name='model_FlappyBird_The_Best_One_gap_125.h5')
master.train()
# Out:
# 8 2
# Loading model from: ./gap_change\model_FlappyBird_The_Best_One_gap_125.h5
# Starting worker 0
# Starting worker 1
# Starting worker 2
# Starting worker 3
# Starting worker 4
# Starting worker 5
# Starting worker 6
# Starting worker 7
# Starting worker 8
# Starting worker 9
# Starting worker 10
# Starting worker 11
# Episode: 0 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.524 | Steps: 210 | Worker: 5
# Saving best model to ./gap_change, episode score: 20.00000000000007
# Episode: 0 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 1.581 | Steps: 210 | Worker: 2
# Saving checkpoint model to ./gap_change, episode score: 20.00000000000007
# Episode: 1 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.914 | Steps: 210 | Worker: 6
# Saving best model to ./gap_change, episode score: 20.00000000000007
# Episode: 2 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.203 | Steps: 210 | Worker: 1
# Episode: 4 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.332 | Steps: 210 | Worker: 11
# Episode: 4 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.943 | Steps: 210 | Worker: 8
# Episode: 6 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.299 | Steps: 210 | Worker: 0
# Episode: 7 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 3.203 | Steps: 210 | Worker: 3
# Episode: 8 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.192 | Steps: 210 | Worker: 7
# Episode: 9 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 2.075 | Steps: 210 | Worker: 9
# Episode: 10 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.332 | Steps: 210 | Worker: 4
# Episode: 11 | Moving Average Reward: 20.00 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.328 | Steps: 210 | Worker: 10
# Episode: 12 | Moving Average Reward: 19.81 | Episode Reward: 1.20 | True Reward: -5.00 |Loss: 0.209 | Steps: 62 | Worker: 11
# Episode: 13 | Moving Average Reward: 19.67 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.126 | Steps: 97 | Worker: 6Episode: 13 | Moving Average Reward: 19.67 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.127 | Steps: 97 | Worker: 5
#
# Episode: 15 | Moving Average Reward: 19.53 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.126 | Steps: 97 | Worker: 2
# Episode: 16 | Moving Average Reward: 19.39 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.128 | Steps: 97 | Worker: 8
# Episode: 17 | Moving Average Reward: 19.26 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.128 | Steps: 97 | Worker: 0
# Episode: 18 | Moving Average Reward: 19.12 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.132 | Steps: 97 | Worker: 9
# Episode: 19 | Moving Average Reward: 19.23 | Episode Reward: 29.70 | True Reward: 1.00 |Loss: 0.073 | Steps: 287 | Worker: 11
# Saving best model to ./gap_change, episode score: 29.70000000000018
# Episode: 20 | Moving Average Reward: 19.33 | Episode Reward: 29.70 | True Reward: 1.00 |Loss: 0.065 | Steps: 287 | Worker: 5
# Episode: 21 | Moving Average Reward: 19.43 | Episode Reward: 29.70 | True Reward: 1.00 |Loss: 0.069 | Steps: 287 | Worker: 6
# Episode: 22 | Moving Average Reward: 19.54 | Episode Reward: 29.70 | True Reward: 1.00 |Loss: 0.07 | Steps: 287 | Worker: 2
# Episode: 23 | Moving Average Reward: 19.75 | Episode Reward: 40.40 | True Reward: 4.00 |Loss: 0.038 | Steps: 364 | Worker: 0
# Saving best model to ./gap_change, episode score: 40.40000000000029
# Episode: 24 | Moving Average Reward: 19.95 | Episode Reward: 40.30 | True Reward: 4.00 |Loss: 0.039 | Steps: 363 | Worker: 8
# Episode: 25 | Moving Average Reward: 20.14 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.038 | Steps: 359 | Worker: 9
# Episode: 26 | Moving Average Reward: 20.06 | Episode Reward: 12.40 | True Reward: -2.00 |Loss: 0.066 | Steps: 144 | Worker: 11
# Episode: 27 | Moving Average Reward: 19.99 | Episode Reward: 12.80 | True Reward: -2.00 |Loss: 0.06 | Steps: 148 | Worker: 5
# Episode: 28 | Moving Average Reward: 19.89 | Episode Reward: 10.40 | True Reward: -3.00 |Loss: 0.075 | Steps: 134 | Worker: 2
# Episode: 29 | Moving Average Reward: 19.82 | Episode Reward: 12.70 | True Reward: -2.00 |Loss: 0.059 | Steps: 147 | Worker: 6
# Episode: 30 | Moving Average Reward: 20.30 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.026 | Steps: 585 | Worker: 1
# Saving best model to ./gap_change, episode score: 67.50000000000013
# Episode: 31 | Moving Average Reward: 20.79 | Episode Reward: 69.60 | True Reward: 10.00 |Loss: 0.024 | Steps: 596 | Worker: 7
# Saving best model to ./gap_change, episode score: 69.60000000000007
# Episode: 31 | Moving Average Reward: 21.26 | Episode Reward: 67.70 | True Reward: 9.00 |Loss: 0.03 | Steps: 587 | Worker: 4
# Episode: 33 | Moving Average Reward: 21.18 | Episode Reward: 12.70 | True Reward: -2.00 |Loss: 0.057 | Steps: 147 | Worker: 9
# Episode: 34 | Moving Average Reward: 21.64 | Episode Reward: 67.80 | True Reward: 9.00 |Loss: 0.027 | Steps: 588 | Worker: 10
# Episode: 35 | Moving Average Reward: 21.53 | Episode Reward: 10.40 | True Reward: -3.00 |Loss: 0.069 | Steps: 134 | Worker: 2
# Episode: 36 | Moving Average Reward: 21.33 | Episode Reward: 1.40 | True Reward: -5.00 |Loss: 0.187 | Steps: 64 | Worker: 9
# Episode: 37 | Moving Average Reward: 21.18 | Episode Reward: 6.00 | True Reward: -4.00 |Loss: 0.068 | Steps: 100 | Worker: 4
# Episode: 38 | Moving Average Reward: 21.02 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.062 | Steps: 97 | Worker: 10
# Episode: 39 | Moving Average Reward: 21.77 | Episode Reward: 96.30 | True Reward: 15.00 |Loss: 0.025 | Steps: 813 | Worker: 3
# Saving best model to ./gap_change, episode score: 96.29999999999883
# Episode: 40 | Moving Average Reward: 21.58 | Episode Reward: 2.50 | True Reward: -4.00 |Loss: 0.136 | Steps: 65 | Worker: 3
# Episode: 41 | Moving Average Reward: 21.71 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.04 | Steps: 323 | Worker: 7
# Episode: 42 | Moving Average Reward: 22.02 | Episode Reward: 53.20 | True Reward: 6.00 |Loss: 0.034 | Steps: 472 | Worker: 1
# Episode: 43 | Moving Average Reward: 22.30 | Episode Reward: 50.00 | True Reward: 6.00 |Loss: 0.028 | Steps: 440 | Worker: 2
# Episode: 44 | Moving Average Reward: 23.05 | Episode Reward: 97.50 | True Reward: 16.00 |Loss: 0.023 | Steps: 815 | Worker: 0
# Saving best model to ./gap_change, episode score: 97.49999999999882
# Episode: 45 | Moving Average Reward: 23.81 | Episode Reward: 98.70 | True Reward: 16.00 |Loss: 0.028 | Steps: 827 | Worker: 8
# Saving best model to ./gap_change, episode score: 98.69999999999875
# Episode: 46 | Moving Average Reward: 23.98 | Episode Reward: 40.60 | True Reward: 4.00 |Loss: 0.034 | Steps: 366 | Worker: 1
# Episode: 47 | Moving Average Reward: 24.84 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.027 | Steps: 924 | Worker: 6
# Saving best model to ./gap_change, episode score: 110.3999999999982
# Episode: 48 | Moving Average Reward: 24.70 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.122 | Steps: 133 | Worker: 1
# Episode: 49 | Moving Average Reward: 25.51 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.027 | Steps: 888 | Worker: 4
# Episode: 50 | Moving Average Reward: 26.60 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.023 | Steps: 1114 | Worker: 9
# Saving best model to ./gap_change, episode score: 134.39999999999714
# Episode: 51 | Moving Average Reward: 26.67 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.038 | Steps: 323 | Worker: 4
# Episode: 52 | Moving Average Reward: 26.51 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.172 | Steps: 133 | Worker: 9
# Episode: 53 | Moving Average Reward: 27.16 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.027 | Steps: 775 | Worker: 0
# Episode: 54 | Moving Average Reward: 27.80 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.026 | Steps: 775 | Worker: 8
# Episode: 55 | Moving Average Reward: 29.20 | Episode Reward: 167.60 | True Reward: 30.00 |Loss: 0.022 | Steps: 1376 | Worker: 10
# Saving best model to ./gap_change, episode score: 167.59999999999565
# Episode: 56 | Moving Average Reward: 29.16 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.043 | Steps: 246 | Worker: 9
# Episode: 57 | Moving Average Reward: 30.49 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.016 | Steps: 1340 | Worker: 3
# Episode: 58 | Moving Average Reward: 31.82 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.018 | Steps: 1340 | Worker: 7
# Episode: 59 | Moving Average Reward: 31.60 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.094 | Steps: 133 | Worker: 10
# Episode: 60 | Moving Average Reward: 33.61 | Episode Reward: 232.40 | True Reward: 44.00 |Loss: 0.018 | Steps: 1884 | Worker: 11
# Saving best model to ./gap_change, episode score: 232.39999999999276
# Episode: 61 | Moving Average Reward: 35.62 | Episode Reward: 234.50 | True Reward: 44.00 |Loss: 0.015 | Steps: 1905 | Worker: 5
# Saving best model to ./gap_change, episode score: 234.49999999999264
# Episode: 62 | Moving Average Reward: 36.51 | Episode Reward: 124.70 | True Reward: 21.00 |Loss: 0.022 | Steps: 1037 | Worker: 6
# Episode: 63 | Moving Average Reward: 36.54 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.049 | Steps: 359 | Worker: 6
# Episode: 64 | Moving Average Reward: 37.13 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.028 | Steps: 811 | Worker: 0
# Episode: 65 | Moving Average Reward: 37.25 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.04 | Steps: 436 | Worker: 5
# Episode: 66 | Moving Average Reward: 37.83 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.022 | Steps: 811 | Worker: 8
# Episode: 67 | Moving Average Reward: 38.80 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.02 | Steps: 1114 | Worker: 4
# Episode: 68 | Moving Average Reward: 39.37 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.017 | Steps: 811 | Worker: 3
# Episode: 69 | Moving Average Reward: 41.10 | Episode Reward: 212.50 | True Reward: 40.00 |Loss: 0.017 | Steps: 1725 | Worker: 1
# Episode: 70 | Moving Average Reward: 41.32 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.023 | Steps: 549 | Worker: 6
# Episode: 71 | Moving Average Reward: 41.30 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.053 | Steps: 359 | Worker: 3
# Episode: 72 | Moving Average Reward: 41.09 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.09 | Steps: 210 | Worker: 6
# Episode: 73 | Moving Average Reward: 40.87 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.063 | Steps: 210 | Worker: 3
# Episode: 74 | Moving Average Reward: 42.28 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.016 | Steps: 1489 | Worker: 9
# Episode: 75 | Moving Average Reward: 42.97 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.016 | Steps: 924 | Worker: 0
# Episode: 76 | Moving Average Reward: 43.64 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.018 | Steps: 924 | Worker: 5
# Episode: 77 | Moving Average Reward: 44.31 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.014 | Steps: 924 | Worker: 8
# Episode: 78 | Moving Average Reward: 44.78 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.019 | Steps: 775 | Worker: 4
# Episode: 79 | Moving Average Reward: 47.72 | Episode Reward: 339.20 | True Reward: 66.00 |Loss: 0.013 | Steps: 2732 | Worker: 2
# Saving best model to ./gap_change, episode score: 339.2000000000079
# Episode: 80 | Moving Average Reward: 47.92 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.017 | Steps: 585 | Worker: 1
# Episode: 80 | Moving Average Reward: 49.07 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.012 | Steps: 1489 | Worker: 11
# Episode: 82 | Moving Average Reward: 48.78 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.057 | Steps: 210 | Worker: 3
# Episode: 83 | Moving Average Reward: 50.49 | Episode Reward: 220.20 | True Reward: 41.00 |Loss: 0.014 | Steps: 1792 | Worker: 7
# Episode: 84 | Moving Average Reward: 50.44 | Episode Reward: 45.80 | True Reward: 5.00 |Loss: 0.052 | Steps: 408 | Worker: 0
# Episode: 85 | Moving Average Reward: 52.24 | Episode Reward: 229.90 | True Reward: 43.00 |Loss: 0.016 | Steps: 1869 | Worker: 10
# Episode: 86 | Moving Average Reward: 52.82 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.022 | Steps: 924 | Worker: 6
# Episode: 87 | Moving Average Reward: 53.39 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.021 | Steps: 924 | Worker: 5
# Episode: 88 | Moving Average Reward: 53.06 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.076 | Steps: 210 | Worker: 6
# Episode: 89 | Moving Average Reward: 53.63 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.019 | Steps: 924 | Worker: 8
# Episode: 90 | Moving Average Reward: 54.20 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.015 | Steps: 924 | Worker: 11
# Episode: 91 | Moving Average Reward: 54.76 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.015 | Steps: 924 | Worker: 2
# Episode: 92 | Moving Average Reward: 55.32 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.016 | Steps: 924 | Worker: 1
# Episode: 93 | Moving Average Reward: 55.87 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.013 | Steps: 924 | Worker: 3
# Episode: 94 | Moving Average Reward: 56.72 | Episode Reward: 140.50 | True Reward: 25.00 |Loss: 0.015 | Steps: 1155 | Worker: 9
# Episode: 95 | Moving Average Reward: 56.83 | Episode Reward: 67.60 | True Reward: 9.00 |Loss: 0.029 | Steps: 586 | Worker: 10
# Episode: 96 | Moving Average Reward: 56.50 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.032 | Steps: 246 | Worker: 5
# Episode: 97 | Moving Average Reward: 56.14 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.043 | Steps: 210 | Worker: 8
# Episode: 98 | Moving Average Reward: 55.78 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.039 | Steps: 210 | Worker: 2
# Episode: 99 | Moving Average Reward: 55.47 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.034 | Steps: 246 | Worker: 11
# Episode: 100 | Moving Average Reward: 55.16 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.038 | Steps: 246 | Worker: 1
# Episode: 101 | Moving Average Reward: 54.85 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.033 | Steps: 246 | Worker: 3
# Episode: 102 | Moving Average Reward: 55.55 | Episode Reward: 124.70 | True Reward: 21.00 |Loss: 0.012 | Steps: 1037 | Worker: 7
# Episode: 103 | Moving Average Reward: 55.24 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.033 | Steps: 246 | Worker: 10
# Episode: 104 | Moving Average Reward: 54.89 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.065 | Steps: 210 | Worker: 7
# Episode: 105 | Moving Average Reward: 54.54 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.047 | Steps: 210 | Worker: 10
# Episode: 106 | Moving Average Reward: 55.31 | Episode Reward: 131.20 | True Reward: 23.00 |Loss: 0.018 | Steps: 1082 | Worker: 6
# Episode: 107 | Moving Average Reward: 56.10 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.012 | Steps: 1114 | Worker: 11
# Episode: 108 | Moving Average Reward: 55.92 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.061 | Steps: 359 | Worker: 6
# Episode: 109 | Moving Average Reward: 55.47 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.106 | Steps: 133 | Worker: 6
# Episode: 110 | Moving Average Reward: 57.69 | Episode Reward: 277.40 | True Reward: 53.00 |Loss: 0.016 | Steps: 2244 | Worker: 0
# Episode: 111 | Moving Average Reward: 58.93 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.017 | Steps: 1489 | Worker: 5
# Episode: 112 | Moving Average Reward: 58.73 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.045 | Steps: 359 | Worker: 11
# Episode: 113 | Moving Average Reward: 59.96 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.013 | Steps: 1489 | Worker: 2
# Episode: 114 | Moving Average Reward: 61.32 | Episode Reward: 196.20 | True Reward: 36.00 |Loss: 0.02 | Steps: 1602 | Worker: 9
# Episode: 115 | Moving Average Reward: 60.96 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.029 | Steps: 246 | Worker: 6
# Episode: 116 | Moving Average Reward: 60.45 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.077 | Steps: 133 | Worker: 5
# Episode: 117 | Moving Average Reward: 59.95 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.042 | Steps: 133 | Worker: 11
# Episode: 118 | Moving Average Reward: 59.45 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.04 | Steps: 133 | Worker: 2
# Episode: 119 | Moving Average Reward: 58.96 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.038 | Steps: 133 | Worker: 9
# Episode: 120 | Moving Average Reward: 58.62 | Episode Reward: 24.70 | True Reward: 0.00 |Loss: 0.055 | Steps: 247 | Worker: 6
# Episode: 121 | Moving Average Reward: 59.85 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.012 | Steps: 1489 | Worker: 7
# Episode: 122 | Moving Average Reward: 61.45 | Episode Reward: 220.20 | True Reward: 41.00 |Loss: 0.013 | Steps: 1792 | Worker: 3
# Episode: 123 | Moving Average Reward: 61.09 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.03 | Steps: 246 | Worker: 2
# Episode: 124 | Moving Average Reward: 62.29 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.01 | Steps: 1489 | Worker: 10
# Episode: 125 | Moving Average Reward: 61.77 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.057 | Steps: 133 | Worker: 7
# Episode: 126 | Moving Average Reward: 61.26 | Episode Reward: 10.50 | True Reward: -3.00 |Loss: 0.138 | Steps: 135 | Worker: 10
# Episode: 127 | Moving Average Reward: 60.89 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.033 | Steps: 246 | Worker: 3
# Episode: 128 | Moving Average Reward: 60.83 | Episode Reward: 54.90 | True Reward: 7.00 |Loss: 0.035 | Steps: 479 | Worker: 9
# Episode: 129 | Moving Average Reward: 60.57 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.037 | Steps: 323 | Worker: 2
# Episode: 130 | Moving Average Reward: 60.78 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.027 | Steps: 698 | Worker: 5
# Episode: 131 | Moving Average Reward: 60.20 | Episode Reward: 3.10 | True Reward: -4.00 |Loss: 0.215 | Steps: 71 | Worker: 2
# Episode: 132 | Moving Average Reward: 59.72 | Episode Reward: 11.70 | True Reward: -2.00 |Loss: 0.09 | Steps: 137 | Worker: 9
# Episode: 133 | Moving Average Reward: 59.94 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.024 | Steps: 698 | Worker: 11
# Episode: 134 | Moving Average Reward: 59.40 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.105 | Steps: 97 | Worker: 5
# Episode: 135 | Moving Average Reward: 59.07 | Episode Reward: 26.70 | True Reward: 1.00 |Loss: 0.067 | Steps: 257 | Worker: 3
# Episode: 136 | Moving Average Reward: 58.54 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.083 | Steps: 97 | Worker: 11
# Episode: 137 | Moving Average Reward: 58.05 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.076 | Steps: 133 | Worker: 3
# Episode: 138 | Moving Average Reward: 60.72 | Episode Reward: 324.90 | True Reward: 63.00 |Loss: 0.014 | Steps: 2619 | Worker: 8
# Episode: 139 | Moving Average Reward: 60.32 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.068 | Steps: 210 | Worker: 11
# Episode: 140 | Moving Average Reward: 60.53 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.024 | Steps: 698 | Worker: 7
# Episode: 141 | Moving Average Reward: 60.03 | Episode Reward: 10.50 | True Reward: -3.00 |Loss: 0.095 | Steps: 135 | Worker: 3
# Episode: 142 | Moving Average Reward: 62.68 | Episode Reward: 324.90 | True Reward: 63.00 |Loss: 0.011 | Steps: 2619 | Worker: 1
# Episode: 143 | Moving Average Reward: 62.11 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.076 | Steps: 97 | Worker: 8
# Episode: 144 | Moving Average Reward: 61.55 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.098 | Steps: 97 | Worker: 11
# Episode: 145 | Moving Average Reward: 60.99 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.081 | Steps: 97 | Worker: 7
# Episode: 146 | Moving Average Reward: 60.43 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.109 | Steps: 97 | Worker: 1
# Episode: 147 | Moving Average Reward: 61.46 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.015 | Steps: 1340 | Worker: 0
# Episode: 148 | Moving Average Reward: 62.05 | Episode Reward: 120.10 | True Reward: 20.00 |Loss: 0.023 | Steps: 1001 | Worker: 6
# Episode: 149 | Moving Average Reward: 62.01 | Episode Reward: 58.30 | True Reward: 7.00 |Loss: 0.017 | Steps: 513 | Worker: 9
# Episode: 150 | Moving Average Reward: 66.45 | Episode Reward: 506.20 | True Reward: 101.00 |Loss: 0.012 | Steps: 4052 | Worker: 4
# Saving best model to ./gap_change, episode score: 506.2000000000379
# Episode: 151 | Moving Average Reward: 65.99 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.078 | Steps: 210 | Worker: 7
# Episode: 152 | Moving Average Reward: 65.53 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.073 | Steps: 210 | Worker: 0
# Episode: 153 | Moving Average Reward: 64.93 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.072 | Steps: 97 | Worker: 7
# Episode: 154 | Moving Average Reward: 65.38 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.012 | Steps: 924 | Worker: 10
# Episode: 155 | Moving Average Reward: 65.17 | Episode Reward: 44.00 | True Reward: 4.00 |Loss: 0.027 | Steps: 400 | Worker: 1
# Episode: 156 | Moving Average Reward: 64.72 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.037 | Steps: 210 | Worker: 4
# Episode: 157 | Moving Average Reward: 65.13 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.014 | Steps: 888 | Worker: 2
# Episode: 158 | Moving Average Reward: 64.87 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.019 | Steps: 359 | Worker: 9
# Episode: 159 | Moving Average Reward: 65.28 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.014 | Steps: 888 | Worker: 5
# Episode: 160 | Moving Average Reward: 65.30 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.026 | Steps: 585 | Worker: 3
# Episode: 161 | Moving Average Reward: 65.27 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.013 | Steps: 549 | Worker: 11
# Episode: 162 | Moving Average Reward: 64.82 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.07 | Steps: 210 | Worker: 10
# Episode: 163 | Moving Average Reward: 64.23 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.049 | Steps: 97 | Worker: 3
# Episode: 164 | Moving Average Reward: 63.79 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.085 | Steps: 210 | Worker: 4
# Episode: 165 | Moving Average Reward: 63.78 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.047 | Steps: 549 | Worker: 0
# Episode: 166 | Moving Average Reward: 64.20 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.027 | Steps: 888 | Worker: 8
# Episode: 167 | Moving Average Reward: 63.61 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.083 | Steps: 97 | Worker: 0
# Episode: 168 | Moving Average Reward: 63.51 | Episode Reward: 53.20 | True Reward: 6.00 |Loss: 0.042 | Steps: 472 | Worker: 9
# Episode: 169 | Moving Average Reward: 63.41 | Episode Reward: 53.20 | True Reward: 6.00 |Loss: 0.03 | Steps: 472 | Worker: 3
# Episode: 170 | Moving Average Reward: 63.40 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.033 | Steps: 549 | Worker: 4
# Episode: 171 | Moving Average Reward: 63.87 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.017 | Steps: 924 | Worker: 7
# Episode: 172 | Moving Average Reward: 63.76 | Episode Reward: 53.20 | True Reward: 6.00 |Loss: 0.027 | Steps: 472 | Worker: 8
# Episode: 173 | Moving Average Reward: 64.33 | Episode Reward: 120.10 | True Reward: 20.00 |Loss: 0.036 | Steps: 1001 | Worker: 11
# Episode: 174 | Moving Average Reward: 65.07 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.027 | Steps: 1150 | Worker: 5
# Episode: 175 | Moving Average Reward: 66.91 | Episode Reward: 248.80 | True Reward: 47.00 |Loss: 0.014 | Steps: 2018 | Worker: 6
# Episode: 176 | Moving Average Reward: 67.49 | Episode Reward: 124.70 | True Reward: 21.00 |Loss: 0.013 | Steps: 1037 | Worker: 3
# Episode: 177 | Moving Average Reward: 68.30 | Episode Reward: 148.70 | True Reward: 26.00 |Loss: 0.028 | Steps: 1227 | Worker: 9
# Episode: 178 | Moving Average Reward: 68.39 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.032 | Steps: 662 | Worker: 5
# Episode: 179 | Moving Average Reward: 70.05 | Episode Reward: 234.50 | True Reward: 44.00 |Loss: 0.02 | Steps: 1905 | Worker: 2
# Episode: 180 | Moving Average Reward: 69.41 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.14 | Steps: 97 | Worker: 5
# Episode: 181 | Moving Average Reward: 69.10 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.044 | Steps: 359 | Worker: 3
# Episode: 182 | Moving Average Reward: 68.47 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.112 | Steps: 97 | Worker: 5
# Episode: 183 | Moving Average Reward: 68.17 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.035 | Steps: 359 | Worker: 9
# Episode: 184 | Moving Average Reward: 69.88 | Episode Reward: 239.10 | True Reward: 45.00 |Loss: 0.017 | Steps: 1941 | Worker: 10
# Episode: 185 | Moving Average Reward: 70.53 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.017 | Steps: 1114 | Worker: 11
# Episode: 186 | Moving Average Reward: 71.45 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.011 | Steps: 1340 | Worker: 8
# Episode: 187 | Moving Average Reward: 71.08 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.031 | Steps: 323 | Worker: 2
# Episode: 188 | Moving Average Reward: 70.62 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.03 | Steps: 246 | Worker: 5
# Episode: 189 | Moving Average Reward: 72.30 | Episode Reward: 239.10 | True Reward: 45.00 |Loss: 0.011 | Steps: 1941 | Worker: 0
# Episode: 190 | Moving Average Reward: 71.64 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.116 | Steps: 97 | Worker: 0
# Episode: 191 | Moving Average Reward: 74.02 | Episode Reward: 310.60 | True Reward: 60.00 |Loss: 0.012 | Steps: 2506 | Worker: 1
# Episode: 192 | Moving Average Reward: 75.39 | Episode Reward: 210.50 | True Reward: 39.00 |Loss: 0.015 | Steps: 1715 | Worker: 7
# Episode: 193 | Moving Average Reward: 74.98 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.029 | Steps: 323 | Worker: 8
# Episode: 194 | Moving Average Reward: 74.29 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.074 | Steps: 97 | Worker: 1
# Episode: 195 | Moving Average Reward: 73.79 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.042 | Steps: 246 | Worker: 8
# Episode: 196 | Moving Average Reward: 75.64 | Episode Reward: 258.50 | True Reward: 49.00 |Loss: 0.013 | Steps: 2095 | Worker: 4
# Episode: 197 | Moving Average Reward: 75.84 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.024 | Steps: 811 | Worker: 5
# Episode: 198 | Moving Average Reward: 76.19 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.017 | Steps: 924 | Worker: 11
# Episode: 199 | Moving Average Reward: 76.63 | Episode Reward: 120.10 | True Reward: 20.00 |Loss: 0.032 | Steps: 1001 | Worker: 10
# Episode: 200 | Moving Average Reward: 77.25 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.019 | Steps: 1150 | Worker: 3
# Episode: 201 | Moving Average Reward: 77.87 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.019 | Steps: 1150 | Worker: 9
# Episode: 202 | Moving Average Reward: 78.19 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.021 | Steps: 924 | Worker: 7
# Episode: 203 | Moving Average Reward: 78.80 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.022 | Steps: 1150 | Worker: 0
# Episode: 204 | Moving Average Reward: 78.97 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.024 | Steps: 811 | Worker: 8
# Episode: 205 | Moving Average Reward: 78.57 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.054 | Steps: 359 | Worker: 9
# Episode: 206 | Moving Average Reward: 80.32 | Episode Reward: 253.40 | True Reward: 48.00 |Loss: 0.016 | Steps: 2054 | Worker: 6
# Episode: 207 | Moving Average Reward: 81.48 | Episode Reward: 196.20 | True Reward: 36.00 |Loss: 0.018 | Steps: 1602 | Worker: 2
# Episode: 208 | Moving Average Reward: 81.05 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.056 | Steps: 359 | Worker: 0
# Episode: 209 | Moving Average Reward: 80.63 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.041 | Steps: 359 | Worker: 8
# Episode: 210 | Moving Average Reward: 80.50 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.018 | Steps: 585 | Worker: 7
# Episode: 211 | Moving Average Reward: 81.18 | Episode Reward: 148.70 | True Reward: 26.00 |Loss: 0.025 | Steps: 1227 | Worker: 4
# Episode: 212 | Moving Average Reward: 81.90 | Episode Reward: 153.30 | True Reward: 27.00 |Loss: 0.014 | Steps: 1263 | Worker: 5
# Episode: 213 | Moving Average Reward: 82.43 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.02 | Steps: 1114 | Worker: 10
# Episode: 214 | Moving Average Reward: 83.38 | Episode Reward: 177.30 | True Reward: 32.00 |Loss: 0.022 | Steps: 1453 | Worker: 11
# Episode: 215 | Moving Average Reward: 83.48 | Episode Reward: 94.00 | True Reward: 15.00 |Loss: 0.022 | Steps: 790 | Worker: 2
# Episode: 216 | Moving Average Reward: 82.99 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.032 | Steps: 323 | Worker: 5
# Episode: 217 | Moving Average Reward: 83.12 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.012 | Steps: 811 | Worker: 7
# Episode: 218 | Moving Average Reward: 82.63 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.034 | Steps: 323 | Worker: 11
# Episode: 219 | Moving Average Reward: 83.34 | Episode Reward: 153.30 | True Reward: 27.00 |Loss: 0.023 | Steps: 1263 | Worker: 6
# Episode: 220 | Moving Average Reward: 85.47 | Episode Reward: 296.30 | True Reward: 57.00 |Loss: 0.013 | Steps: 2393 | Worker: 1
# Episode: 221 | Moving Average Reward: 84.96 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.03 | Steps: 323 | Worker: 7
# Episode: 222 | Moving Average Reward: 86.45 | Episode Reward: 234.50 | True Reward: 44.00 |Loss: 0.017 | Steps: 1905 | Worker: 3
# Episode: 223 | Moving Average Reward: 87.12 | Episode Reward: 153.30 | True Reward: 27.00 |Loss: 0.013 | Steps: 1263 | Worker: 8
# Episode: 224 | Moving Average Reward: 86.31 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.065 | Steps: 97 | Worker: 3
# Episode: 225 | Moving Average Reward: 85.83 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.036 | Steps: 359 | Worker: 11
# Episode: 226 | Moving Average Reward: 85.08 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.079 | Steps: 133 | Worker: 3
# Episode: 227 | Moving Average Reward: 85.19 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.028 | Steps: 811 | Worker: 2
# Episode: 228 | Moving Average Reward: 84.39 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.108 | Steps: 97 | Worker: 3
# Episode: 229 | Moving Average Reward: 83.94 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.03 | Steps: 359 | Worker: 7
# Episode: 230 | Moving Average Reward: 83.44 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.025 | Steps: 323 | Worker: 11
# Episode: 231 | Moving Average Reward: 84.00 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.014 | Steps: 1150 | Worker: 10
# Episode: 232 | Moving Average Reward: 84.36 | Episode Reward: 120.10 | True Reward: 20.00 |Loss: 0.026 | Steps: 1001 | Worker: 5
# Episode: 233 | Moving Average Reward: 86.19 | Episode Reward: 267.70 | True Reward: 51.00 |Loss: 0.012 | Steps: 2167 | Worker: 9
# Episode: 234 | Moving Average Reward: 85.82 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.03 | Steps: 436 | Worker: 10
# Episode: 235 | Moving Average Reward: 86.26 | Episode Reward: 129.80 | True Reward: 22.00 |Loss: 0.034 | Steps: 1078 | Worker: 1
# Episode: 236 | Moving Average Reward: 88.07 | Episode Reward: 267.70 | True Reward: 51.00 |Loss: 0.012 | Steps: 2167 | Worker: 0
# Episode: 237 | Moving Average Reward: 88.31 | Episode Reward: 112.20 | True Reward: 19.00 |Loss: 0.025 | Steps: 932 | Worker: 8
# Episode: 238 | Moving Average Reward: 87.98 | Episode Reward: 54.90 | True Reward: 7.00 |Loss: 0.045 | Steps: 479 | Worker: 5
# Episode: 239 | Moving Average Reward: 89.73 | Episode Reward: 263.10 | True Reward: 50.00 |Loss: 0.01 | Steps: 2131 | Worker: 4
# Episode: 240 | Moving Average Reward: 89.03 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.056 | Steps: 210 | Worker: 5
# Episode: 241 | Moving Average Reward: 90.06 | Episode Reward: 191.60 | True Reward: 35.00 |Loss: 0.015 | Steps: 1566 | Worker: 6
# Episode: 242 | Moving Average Reward: 89.55 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.052 | Steps: 359 | Worker: 8
# Episode: 243 | Moving Average Reward: 88.99 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.048 | Steps: 323 | Worker: 4
# Episode: 244 | Moving Average Reward: 89.45 | Episode Reward: 134.50 | True Reward: 23.00 |Loss: 0.018 | Steps: 1115 | Worker: 7
# Episode: 245 | Moving Average Reward: 89.37 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.027 | Steps: 698 | Worker: 10
# Episode: 246 | Moving Average Reward: 88.87 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.032 | Steps: 359 | Worker: 8
# Episode: 247 | Moving Average Reward: 90.18 | Episode Reward: 220.20 | True Reward: 41.00 |Loss: 0.017 | Steps: 1792 | Worker: 2
# Episode: 248 | Moving Average Reward: 91.05 | Episode Reward: 177.50 | True Reward: 32.00 |Loss: 0.016 | Steps: 1455 | Worker: 9
# Episode: 249 | Moving Average Reward: 91.06 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.02 | Steps: 775 | Worker: 4
# Episode: 250 | Moving Average Reward: 92.40 | Episode Reward: 224.80 | True Reward: 42.00 |Loss: 0.016 | Steps: 1828 | Worker: 11
# Episode: 251 | Moving Average Reward: 92.58 | Episode Reward: 110.70 | True Reward: 18.00 |Loss: 0.027 | Steps: 927 | Worker: 6
# Episode: 252 | Moving Average Reward: 93.45 | Episode Reward: 179.20 | True Reward: 33.00 |Loss: 0.016 | Steps: 1462 | Worker: 0
# Episode: 253 | Moving Average Reward: 93.43 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.019 | Steps: 775 | Worker: 10
# Episode: 254 | Moving Average Reward: 93.52 | Episode Reward: 103.00 | True Reward: 17.00 |Loss: 0.03 | Steps: 860 | Worker: 8
# Episode: 255 | Moving Average Reward: 93.22 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.024 | Steps: 549 | Worker: 9
# Episode: 256 | Moving Average Reward: 94.06 | Episode Reward: 177.30 | True Reward: 32.00 |Loss: 0.015 | Steps: 1453 | Worker: 5
# Episode: 257 | Moving Average Reward: 93.89 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.022 | Steps: 662 | Worker: 2
# Episode: 258 | Moving Average Reward: 93.53 | Episode Reward: 58.30 | True Reward: 7.00 |Loss: 0.034 | Steps: 513 | Worker: 6
# Episode: 259 | Moving Average Reward: 95.66 | Episode Reward: 306.00 | True Reward: 59.00 |Loss: 0.014 | Steps: 2470 | Worker: 3
# Episode: 260 | Moving Average Reward: 94.80 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.059 | Steps: 133 | Worker: 5
# Episode: 261 | Moving Average Reward: 93.91 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.081 | Steps: 97 | Worker: 6
# Episode: 262 | Moving Average Reward: 93.17 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.043 | Steps: 210 | Worker: 9
# Episode: 263 | Moving Average Reward: 92.30 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.102 | Steps: 97 | Worker: 3
# Episode: 264 | Moving Average Reward: 91.43 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.106 | Steps: 97 | Worker: 5
# Episode: 265 | Moving Average Reward: 91.19 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.033 | Steps: 585 | Worker: 0
# Episode: 266 | Moving Average Reward: 90.34 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.071 | Steps: 97 | Worker: 9
# Episode: 267 | Moving Average Reward: 89.54 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.058 | Steps: 133 | Worker: 3
# Episode: 268 | Moving Average Reward: 89.03 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.035 | Steps: 359 | Worker: 2
# Episode: 269 | Moving Average Reward: 88.20 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.075 | Steps: 97 | Worker: 3
# Episode: 270 | Moving Average Reward: 87.90 | Episode Reward: 58.30 | True Reward: 7.00 |Loss: 0.029 | Steps: 513 | Worker: 8
# Episode: 271 | Moving Average Reward: 87.17 | Episode Reward: 15.40 | True Reward: -2.00 |Loss: 0.059 | Steps: 174 | Worker: 0
# Episode: 272 | Moving Average Reward: 86.65 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.055 | Steps: 323 | Worker: 6
# Episode: 273 | Moving Average Reward: 87.94 | Episode Reward: 215.60 | True Reward: 40.00 |Loss: 0.012 | Steps: 1756 | Worker: 7
# Episode: 274 | Moving Average Reward: 90.02 | Episode Reward: 296.30 | True Reward: 57.00 |Loss: 0.012 | Steps: 2393 | Worker: 1
# Episode: 275 | Moving Average Reward: 89.46 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.038 | Steps: 323 | Worker: 9
# Episode: 276 | Moving Average Reward: 88.81 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.051 | Steps: 246 | Worker: 7
# Episode: 277 | Moving Average Reward: 88.08 | Episode Reward: 15.40 | True Reward: -2.00 |Loss: 0.057 | Steps: 174 | Worker: 1
# Episode: 278 | Moving Average Reward: 87.59 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.044 | Steps: 359 | Worker: 2
# Episode: 279 | Moving Average Reward: 87.10 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.027 | Steps: 359 | Worker: 6
# Episode: 280 | Moving Average Reward: 86.29 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.069 | Steps: 97 | Worker: 1
# Episode: 281 | Moving Average Reward: 86.01 | Episode Reward: 58.30 | True Reward: 7.00 |Loss: 0.034 | Steps: 513 | Worker: 0
# Episode: 282 | Moving Average Reward: 85.35 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.061 | Steps: 210 | Worker: 6
# Episode: 283 | Moving Average Reward: 84.88 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.033 | Steps: 359 | Worker: 7
# Episode: 284 | Moving Average Reward: 84.85 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.021 | Steps: 698 | Worker: 8
# Episode: 285 | Moving Average Reward: 84.39 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.021 | Steps: 359 | Worker: 2
# Episode: 286 | Moving Average Reward: 83.94 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.047 | Steps: 359 | Worker: 1
# Episode: 287 | Moving Average Reward: 84.06 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.02 | Steps: 811 | Worker: 3
# Episode: 288 | Moving Average Reward: 84.04 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.018 | Steps: 698 | Worker: 9
# Episode: 289 | Moving Average Reward: 83.58 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.028 | Steps: 359 | Worker: 0
# Episode: 290 | Moving Average Reward: 84.09 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.014 | Steps: 1114 | Worker: 5
# Episode: 291 | Moving Average Reward: 83.50 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.025 | Steps: 246 | Worker: 7
# Episode: 292 | Moving Average Reward: 82.77 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.082 | Steps: 133 | Worker: 3
# Episode: 293 | Moving Average Reward: 82.33 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.026 | Steps: 359 | Worker: 6
# Episode: 294 | Moving Average Reward: 83.89 | Episode Reward: 239.10 | True Reward: 45.00 |Loss: 0.012 | Steps: 1941 | Worker: 4
# Episode: 295 | Moving Average Reward: 85.54 | Episode Reward: 248.80 | True Reward: 47.00 |Loss: 0.014 | Steps: 2018 | Worker: 11
# Episode: 296 | Moving Average Reward: 84.75 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.107 | Steps: 97 | Worker: 4
# Episode: 297 | Moving Average Reward: 84.14 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.034 | Steps: 246 | Worker: 9
# Episode: 298 | Moving Average Reward: 85.46 | Episode Reward: 215.60 | True Reward: 40.00 |Loss: 0.013 | Steps: 1756 | Worker: 10
# Episode: 299 | Moving Average Reward: 84.85 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.04 | Steps: 246 | Worker: 0
# Episode: 300 | Moving Average Reward: 84.25 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.038 | Steps: 246 | Worker: 5
# Episode: 301 | Moving Average Reward: 83.79 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.033 | Steps: 359 | Worker: 1
# Episode: 302 | Moving Average Reward: 83.20 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.027 | Steps: 246 | Worker: 7
# Episode: 303 | Moving Average Reward: 82.43 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.051 | Steps: 97 | Worker: 11
# Episode: 304 | Moving Average Reward: 81.85 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.018 | Steps: 246 | Worker: 6
# Episode: 305 | Moving Average Reward: 81.33 | Episode Reward: 29.70 | True Reward: 1.00 |Loss: 0.027 | Steps: 287 | Worker: 3
# Episode: 306 | Moving Average Reward: 81.14 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.02 | Steps: 549 | Worker: 8
# Episode: 307 | Moving Average Reward: 80.58 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.017 | Steps: 246 | Worker: 9
# Episode: 308 | Moving Average Reward: 80.54 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.026 | Steps: 662 | Worker: 2
# Episode: 309 | Moving Average Reward: 79.98 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.036 | Steps: 246 | Worker: 1
# Episode: 310 | Moving Average Reward: 79.43 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.027 | Steps: 246 | Worker: 7
# Episode: 311 | Moving Average Reward: 79.08 | Episode Reward: 44.00 | True Reward: 4.00 |Loss: 0.024 | Steps: 400 | Worker: 4
# Episode: 312 | Moving Average Reward: 78.63 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.031 | Steps: 323 | Worker: 8
# Episode: 313 | Moving Average Reward: 78.09 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.037 | Steps: 246 | Worker: 2
# Episode: 314 | Moving Average Reward: 77.55 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.03 | Steps: 246 | Worker: 1
# Episode: 315 | Moving Average Reward: 77.50 | Episode Reward: 72.60 | True Reward: 10.00 |Loss: 0.032 | Steps: 626 | Worker: 0
# Episode: 316 | Moving Average Reward: 77.55 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.024 | Steps: 698 | Worker: 10
# Episode: 317 | Moving Average Reward: 77.02 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.024 | Steps: 246 | Worker: 1
# Episode: 318 | Moving Average Reward: 77.30 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.019 | Steps: 888 | Worker: 5
# Episode: 319 | Moving Average Reward: 77.59 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.018 | Steps: 888 | Worker: 6
# Episode: 320 | Moving Average Reward: 77.49 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.031 | Steps: 585 | Worker: 4
# Episode: 321 | Moving Average Reward: 76.96 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.026 | Steps: 246 | Worker: 10
# Episode: 322 | Moving Average Reward: 77.20 | Episode Reward: 101.20 | True Reward: 16.00 |Loss: 0.019 | Steps: 852 | Worker: 3
# Episode: 323 | Moving Average Reward: 77.68 | Episode Reward: 124.70 | True Reward: 21.00 |Loss: 0.018 | Steps: 1037 | Worker: 11
# Episode: 324 | Moving Average Reward: 77.10 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.051 | Steps: 210 | Worker: 5
# Episode: 325 | Moving Average Reward: 77.39 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.014 | Steps: 888 | Worker: 9
# Episode: 326 | Moving Average Reward: 77.67 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.015 | Steps: 888 | Worker: 7
# Episode: 327 | Moving Average Reward: 77.14 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.023 | Steps: 246 | Worker: 10
# Episode: 328 | Moving Average Reward: 77.33 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.016 | Steps: 811 | Worker: 8
# Episode: 329 | Moving Average Reward: 77.33 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.017 | Steps: 662 | Worker: 0
# Episode: 330 | Moving Average Reward: 76.90 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.021 | Steps: 323 | Worker: 3
# Episode: 331 | Moving Average Reward: 76.33 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.033 | Steps: 210 | Worker: 5
# Episode: 332 | Moving Average Reward: 76.62 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.018 | Steps: 888 | Worker: 2
# Episode: 333 | Moving Average Reward: 76.34 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.023 | Steps: 436 | Worker: 6
# Episode: 334 | Moving Average Reward: 76.07 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.021 | Steps: 436 | Worker: 4
# Episode: 335 | Moving Average Reward: 75.79 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.03 | Steps: 436 | Worker: 9
# Episode: 336 | Moving Average Reward: 75.52 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.03 | Steps: 436 | Worker: 7
# Episode: 337 | Moving Average Reward: 75.15 | Episode Reward: 38.90 | True Reward: 3.00 |Loss: 0.027 | Steps: 359 | Worker: 8
# Episode: 338 | Moving Average Reward: 75.46 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.015 | Steps: 888 | Worker: 1
# Episode: 339 | Moving Average Reward: 75.43 | Episode Reward: 72.60 | True Reward: 10.00 |Loss: 0.022 | Steps: 626 | Worker: 11
# Episode: 340 | Moving Average Reward: 75.16 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.025 | Steps: 436 | Worker: 2
# Episode: 341 | Moving Average Reward: 75.14 | Episode Reward: 72.60 | True Reward: 10.00 |Loss: 0.027 | Steps: 626 | Worker: 0
# Episode: 342 | Moving Average Reward: 74.73 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.03 | Steps: 323 | Worker: 1
# Episode: 343 | Moving Average Reward: 74.75 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.02 | Steps: 662 | Worker: 4
# Episode: 344 | Moving Average Reward: 74.88 | Episode Reward: 86.90 | True Reward: 13.00 |Loss: 0.018 | Steps: 739 | Worker: 6
# Episode: 345 | Moving Average Reward: 75.00 | Episode Reward: 86.90 | True Reward: 13.00 |Loss: 0.022 | Steps: 739 | Worker: 9
# Episode: 346 | Moving Average Reward: 75.69 | Episode Reward: 144.10 | True Reward: 25.00 |Loss: 0.016 | Steps: 1191 | Worker: 10
# Episode: 347 | Moving Average Reward: 75.99 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.021 | Steps: 888 | Worker: 8
# Episode: 348 | Moving Average Reward: 75.71 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.022 | Steps: 436 | Worker: 4
# Episode: 349 | Moving Average Reward: 75.83 | Episode Reward: 86.90 | True Reward: 13.00 |Loss: 0.018 | Steps: 739 | Worker: 0
# Episode: 350 | Moving Average Reward: 76.70 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.015 | Steps: 1340 | Worker: 3
# Episode: 351 | Moving Average Reward: 76.42 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.025 | Steps: 436 | Worker: 10
# Episode: 352 | Moving Average Reward: 77.14 | Episode Reward: 148.70 | True Reward: 26.00 |Loss: 0.022 | Steps: 1227 | Worker: 11
# Episode: 353 | Moving Average Reward: 77.24 | Episode Reward: 86.90 | True Reward: 13.00 |Loss: 0.024 | Steps: 739 | Worker: 4
# Episode: 354 | Moving Average Reward: 77.86 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.017 | Steps: 1150 | Worker: 6
# Episode: 355 | Moving Average Reward: 77.85 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.017 | Steps: 662 | Worker: 3
# Episode: 356 | Moving Average Reward: 79.70 | Episode Reward: 263.10 | True Reward: 50.00 |Loss: 0.018 | Steps: 2131 | Worker: 5
# Episode: 357 | Moving Average Reward: 79.12 | Episode Reward: 21.40 | True Reward: 0.00 |Loss: 0.038 | Steps: 214 | Worker: 6
# Episode: 358 | Moving Average Reward: 78.57 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.023 | Steps: 246 | Worker: 3
# Episode: 359 | Moving Average Reward: 80.28 | Episode Reward: 248.80 | True Reward: 47.00 |Loss: 0.015 | Steps: 2018 | Worker: 7
# Episode: 360 | Moving Average Reward: 80.86 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.01 | Steps: 1150 | Worker: 8
# Episode: 361 | Moving Average Reward: 81.83 | Episode Reward: 177.30 | True Reward: 32.00 |Loss: 0.013 | Steps: 1453 | Worker: 9
# Episode: 362 | Moving Average Reward: 83.45 | Episode Reward: 244.20 | True Reward: 46.00 |Loss: 0.018 | Steps: 1982 | Worker: 2
# Episode: 363 | Moving Average Reward: 82.86 | Episode Reward: 24.60 | True Reward: 0.00 |Loss: 0.038 | Steps: 246 | Worker: 8
# Episode: 364 | Moving Average Reward: 83.57 | Episode Reward: 153.30 | True Reward: 27.00 |Loss: 0.02 | Steps: 1263 | Worker: 0
# Episode: 365 | Moving Average Reward: 83.41 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.03 | Steps: 585 | Worker: 6
# ...
# Episode: 622 | Moving Average Reward: 93.02 | Episode Reward: 34.30 | True Reward: 2.00 |Loss: 0.023 | Steps: 323 | Worker: 0
# Episode: 623 | Moving Average Reward: 92.15 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.042 | Steps: 97 | Worker: 11
# Episode: 624 | Moving Average Reward: 91.43 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.044 | Steps: 210 | Worker: 1
# Episode: 625 | Moving Average Reward: 94.33 | Episode Reward: 382.10 | True Reward: 75.00 |Loss: 0.013 | Steps: 3071 | Worker: 7
# Episode: 626 | Moving Average Reward: 93.88 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.045 | Steps: 436 | Worker: 6
# Episode: 627 | Moving Average Reward: 93.09 | Episode Reward: 15.40 | True Reward: -2.00 |Loss: 0.071 | Steps: 174 | Worker: 0
# Episode: 628 | Moving Average Reward: 92.89 | Episode Reward: 72.60 | True Reward: 10.00 |Loss: 0.026 | Steps: 626 | Worker: 8
# Episode: 629 | Moving Average Reward: 92.16 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.054 | Steps: 210 | Worker: 1
# Episode: 630 | Moving Average Reward: 91.29 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.041 | Steps: 97 | Worker: 8
# Episode: 631 | Moving Average Reward: 90.58 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.054 | Steps: 210 | Worker: 1
# Episode: 632 | Moving Average Reward: 89.73 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.025 | Steps: 97 | Worker: 1
# Episode: 633 | Moving Average Reward: 90.37 | Episode Reward: 153.30 | True Reward: 27.00 |Loss: 0.017 | Steps: 1263 | Worker: 10
# Episode: 634 | Moving Average Reward: 90.38 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.015 | Steps: 775 | Worker: 6
# Episode: 635 | Moving Average Reward: 90.39 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.016 | Steps: 775 | Worker: 0
# Episode: 636 | Moving Average Reward: 90.73 | Episode Reward: 124.70 | True Reward: 21.00 |Loss: 0.017 | Steps: 1037 | Worker: 2
# Episode: 637 | Moving Average Reward: 92.07 | Episode Reward: 224.80 | True Reward: 42.00 |Loss: 0.012 | Steps: 1828 | Worker: 4
# Episode: 638 | Moving Average Reward: 91.35 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.062 | Steps: 210 | Worker: 0
# Episode: 639 | Moving Average Reward: 90.50 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.02 | Steps: 97 | Worker: 4
# Episode: 640 | Moving Average Reward: 89.79 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.057 | Steps: 210 | Worker: 2
# Episode: 641 | Moving Average Reward: 89.71 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.019 | Steps: 698 | Worker: 1
# Episode: 642 | Moving Average Reward: 88.97 | Episode Reward: 15.40 | True Reward: -2.00 |Loss: 0.046 | Steps: 174 | Worker: 0
# Episode: 643 | Moving Average Reward: 88.23 | Episode Reward: 15.40 | True Reward: -2.00 |Loss: 0.039 | Steps: 174 | Worker: 2
# Episode: 644 | Moving Average Reward: 87.88 | Episode Reward: 53.20 | True Reward: 6.00 |Loss: 0.023 | Steps: 472 | Worker: 6
# Episode: 645 | Moving Average Reward: 88.73 | Episode Reward: 172.70 | True Reward: 31.00 |Loss: 0.012 | Steps: 1417 | Worker: 11
# Episode: 646 | Moving Average Reward: 89.90 | Episode Reward: 205.90 | True Reward: 38.00 |Loss: 0.011 | Steps: 1679 | Worker: 5
# Episode: 647 | Moving Average Reward: 89.11 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.069 | Steps: 133 | Worker: 0
# Episode: 648 | Moving Average Reward: 90.13 | Episode Reward: 191.60 | True Reward: 35.00 |Loss: 0.013 | Steps: 1566 | Worker: 3
# Episode: 649 | Moving Average Reward: 89.33 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.071 | Steps: 133 | Worker: 2
# Episode: 650 | Moving Average Reward: 89.83 | Episode Reward: 139.00 | True Reward: 24.00 |Loss: 0.014 | Steps: 1150 | Worker: 8
# Episode: 651 | Moving Average Reward: 89.03 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.066 | Steps: 133 | Worker: 6
# Episode: 652 | Moving Average Reward: 88.22 | Episode Reward: 7.90 | True Reward: -3.00 |Loss: 0.055 | Steps: 109 | Worker: 11
# Episode: 653 | Moving Average Reward: 88.25 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.018 | Steps: 775 | Worker: 10
# Episode: 654 | Moving Average Reward: 89.33 | Episode Reward: 196.20 | True Reward: 36.00 |Loss: 0.016 | Steps: 1602 | Worker: 7
# Episode: 655 | Moving Average Reward: 88.50 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.024 | Steps: 97 | Worker: 10
# Episode: 656 | Moving Average Reward: 88.43 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.016 | Steps: 698 | Worker: 4
# Episode: 657 | Moving Average Reward: 88.03 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.015 | Steps: 436 | Worker: 8
# Episode: 658 | Moving Average Reward: 87.97 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.016 | Steps: 698 | Worker: 5
# Episode: 659 | Moving Average Reward: 87.91 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.014 | Steps: 698 | Worker: 0
# Episode: 660 | Moving Average Reward: 87.85 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.01 | Steps: 698 | Worker: 2
# Episode: 661 | Moving Average Reward: 87.79 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.012 | Steps: 698 | Worker: 6
# Episode: 662 | Moving Average Reward: 87.73 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.011 | Steps: 698 | Worker: 11
# Episode: 663 | Moving Average Reward: 87.76 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.015 | Steps: 775 | Worker: 3
# Episode: 664 | Moving Average Reward: 89.90 | Episode Reward: 301.40 | True Reward: 58.00 |Loss: 0.014 | Steps: 2434 | Worker: 9
# Episode: 665 | Moving Average Reward: 89.82 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.021 | Steps: 698 | Worker: 10
# Episode: 666 | Moving Average Reward: 89.98 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.014 | Steps: 888 | Worker: 7
# Episode: 667 | Moving Average Reward: 89.90 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.01 | Steps: 698 | Worker: 8
# Episode: 668 | Moving Average Reward: 90.96 | Episode Reward: 196.20 | True Reward: 36.00 |Loss: 0.014 | Steps: 1602 | Worker: 1
# Episode: 669 | Moving Average Reward: 90.73 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.034 | Steps: 585 | Worker: 9
# Episode: 670 | Moving Average Reward: 90.78 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.02 | Steps: 811 | Worker: 3
# Episode: 671 | Moving Average Reward: 90.55 | Episode Reward: 67.50 | True Reward: 9.00 |Loss: 0.017 | Steps: 585 | Worker: 10
# Episode: 672 | Moving Average Reward: 91.27 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.015 | Steps: 1340 | Worker: 4
# Episode: 673 | Moving Average Reward: 90.46 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.073 | Steps: 133 | Worker: 10
# Episode: 674 | Moving Average Reward: 89.76 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.057 | Steps: 210 | Worker: 4
# Episode: 675 | Moving Average Reward: 90.54 | Episode Reward: 167.60 | True Reward: 30.00 |Loss: 0.017 | Steps: 1376 | Worker: 5
# Episode: 676 | Moving Average Reward: 91.31 | Episode Reward: 167.60 | True Reward: 30.00 |Loss: 0.022 | Steps: 1376 | Worker: 0
# Episode: 677 | Moving Average Reward: 92.07 | Episode Reward: 167.60 | True Reward: 30.00 |Loss: 0.016 | Steps: 1376 | Worker: 2
# Episode: 678 | Moving Average Reward: 91.73 | Episode Reward: 58.30 | True Reward: 7.00 |Loss: 0.029 | Steps: 513 | Worker: 3
# Episode: 679 | Moving Average Reward: 92.59 | Episode Reward: 177.30 | True Reward: 32.00 |Loss: 0.011 | Steps: 1453 | Worker: 11
# Episode: 680 | Moving Average Reward: 93.34 | Episode Reward: 167.60 | True Reward: 30.00 |Loss: 0.018 | Steps: 1376 | Worker: 7
# Episode: 681 | Moving Average Reward: 93.22 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.012 | Steps: 698 | Worker: 10
# Episode: 682 | Moving Average Reward: 94.68 | Episode Reward: 239.10 | True Reward: 45.00 |Loss: 0.014 | Steps: 1941 | Worker: 6
# Episode: 683 | Moving Average Reward: 95.41 | Episode Reward: 167.60 | True Reward: 30.00 |Loss: 0.02 | Steps: 1376 | Worker: 1
# Episode: 684 | Moving Average Reward: 95.66 | Episode Reward: 120.10 | True Reward: 20.00 |Loss: 0.035 | Steps: 1001 | Worker: 11
# Episode: 685 | Moving Average Reward: 94.80 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.082 | Steps: 133 | Worker: 11
# Episode: 686 | Moving Average Reward: 94.67 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.024 | Steps: 698 | Worker: 6
# Episode: 687 | Moving Average Reward: 96.26 | Episode Reward: 253.40 | True Reward: 48.00 |Loss: 0.019 | Steps: 2054 | Worker: 9
# Episode: 688 | Moving Average Reward: 97.26 | Episode Reward: 196.20 | True Reward: 36.00 |Loss: 0.016 | Steps: 1602 | Worker: 3
# Episode: 689 | Moving Average Reward: 97.85 | Episode Reward: 155.80 | True Reward: 28.00 |Loss: 0.027 | Steps: 1278 | Worker: 10
# Episode: 690 | Moving Average Reward: 99.21 | Episode Reward: 234.50 | True Reward: 44.00 |Loss: 0.015 | Steps: 1905 | Worker: 2
# Episode: 691 | Moving Average Reward: 98.85 | Episode Reward: 62.90 | True Reward: 8.00 |Loss: 0.019 | Steps: 549 | Worker: 9
# Episode: 692 | Moving Average Reward: 98.96 | Episode Reward: 110.40 | True Reward: 18.00 |Loss: 0.017 | Steps: 924 | Worker: 6
# Episode: 693 | Moving Average Reward: 100.80 | Episode Reward: 282.00 | True Reward: 54.00 |Loss: 0.013 | Steps: 2280 | Worker: 0
# Episode: 694 | Moving Average Reward: 102.70 | Episode Reward: 291.70 | True Reward: 56.00 |Loss: 0.014 | Steps: 2357 | Worker: 5
# Episode: 695 | Moving Average Reward: 101.73 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.1 | Steps: 97 | Worker: 6
# Episode: 696 | Moving Average Reward: 100.77 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.083 | Steps: 97 | Worker: 0
# Episode: 697 | Moving Average Reward: 100.58 | Episode Reward: 81.80 | True Reward: 12.00 |Loss: 0.011 | Steps: 698 | Worker: 3
# Episode: 698 | Moving Average Reward: 99.85 | Episode Reward: 27.10 | True Reward: 1.00 |Loss: 0.06 | Steps: 261 | Worker: 9
# Episode: 699 | Moving Average Reward: 98.91 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.047 | Steps: 97 | Worker: 9
# Episode: 700 | Moving Average Reward: 102.12 | Episode Reward: 420.40 | True Reward: 83.00 |Loss: 0.01 | Steps: 3374 | Worker: 8
# Episode: 701 | Moving Average Reward: 104.49 | Episode Reward: 339.20 | True Reward: 66.00 |Loss: 0.012 | Steps: 2732 | Worker: 4
# Episode: 702 | Moving Average Reward: 103.93 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.024 | Steps: 436 | Worker: 5
# Episode: 703 | Moving Average Reward: 105.81 | Episode Reward: 291.70 | True Reward: 56.00 |Loss: 0.009 | Steps: 2357 | Worker: 7
# Episode: 704 | Moving Average Reward: 104.86 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.064 | Steps: 133 | Worker: 4
# Episode: 705 | Moving Average Reward: 104.58 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.024 | Steps: 662 | Worker: 0
# Episode: 706 | Moving Average Reward: 106.35 | Episode Reward: 282.00 | True Reward: 54.00 |Loss: 0.013 | Steps: 2280 | Worker: 1
# Episode: 707 | Moving Average Reward: 105.35 | Episode Reward: 5.70 | True Reward: -4.00 |Loss: 0.047 | Steps: 97 | Worker: 1
# Episode: 708 | Moving Average Reward: 104.78 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.026 | Steps: 436 | Worker: 7
# Episode: 709 | Moving Average Reward: 104.81 | Episode Reward: 107.70 | True Reward: 18.00 |Loss: 0.019 | Steps: 897 | Worker: 8
# Episode: 710 | Moving Average Reward: 104.82 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.013 | Steps: 888 | Worker: 5
# Episode: 711 | Moving Average Reward: 105.40 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.013 | Steps: 1340 | Worker: 3
# Episode: 712 | Moving Average Reward: 107.55 | Episode Reward: 320.30 | True Reward: 62.00 |Loss: 0.011 | Steps: 2583 | Worker: 11
# Episode: 713 | Moving Average Reward: 108.82 | Episode Reward: 234.50 | True Reward: 44.00 |Loss: 0.012 | Steps: 1905 | Worker: 2
# Episode: 714 | Moving Average Reward: 107.83 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.112 | Steps: 133 | Worker: 11
# Episode: 715 | Moving Average Reward: 107.81 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.016 | Steps: 888 | Worker: 7
# Episode: 716 | Moving Average Reward: 108.37 | Episode Reward: 163.00 | True Reward: 29.00 |Loss: 0.012 | Steps: 1340 | Worker: 4
# Episode: 717 | Moving Average Reward: 110.06 | Episode Reward: 277.40 | True Reward: 53.00 |Loss: 0.008 | Steps: 2244 | Worker: 10
# Episode: 718 | Moving Average Reward: 109.06 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.096 | Steps: 133 | Worker: 7
# Episode: 719 | Moving Average Reward: 109.03 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.01 | Steps: 888 | Worker: 8
# Episode: 720 | Moving Average Reward: 108.16 | Episode Reward: 22.10 | True Reward: 0.00 |Loss: 0.038 | Steps: 221 | Worker: 10
# Episode: 721 | Moving Average Reward: 107.18 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.064 | Steps: 133 | Worker: 8
# Episode: 722 | Moving Average Reward: 106.55 | Episode Reward: 44.00 | True Reward: 4.00 |Loss: 0.049 | Steps: 400 | Worker: 10
# Episode: 723 | Moving Average Reward: 107.83 | Episode Reward: 234.50 | True Reward: 44.00 |Loss: 0.011 | Steps: 1905 | Worker: 0
# Episode: 724 | Moving Average Reward: 108.24 | Episode Reward: 148.70 | True Reward: 26.00 |Loss: 0.021 | Steps: 1227 | Worker: 3
# Episode: 725 | Moving Average Reward: 108.21 | Episode Reward: 105.80 | True Reward: 17.00 |Loss: 0.017 | Steps: 888 | Worker: 4
# Episode: 726 | Moving Average Reward: 107.54 | Episode Reward: 41.40 | True Reward: 4.00 |Loss: 0.032 | Steps: 374 | Worker: 0
# Episode: 727 | Moving Average Reward: 108.67 | Episode Reward: 220.20 | True Reward: 41.00 |Loss: 0.017 | Steps: 1792 | Worker: 5
# Episode: 728 | Moving Average Reward: 111.45 | Episode Reward: 387.20 | True Reward: 76.00 |Loss: 0.014 | Steps: 3112 | Worker: 6
# Episode: 729 | Moving Average Reward: 110.83 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.04 | Steps: 436 | Worker: 3
# Episode: 730 | Moving Average Reward: 111.54 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.012 | Steps: 1489 | Worker: 11
# Episode: 731 | Moving Average Reward: 113.53 | Episode Reward: 310.60 | True Reward: 60.00 |Loss: 0.012 | Steps: 2506 | Worker: 1
# Episode: 732 | Moving Average Reward: 113.31 | Episode Reward: 91.50 | True Reward: 14.00 |Loss: 0.014 | Steps: 775 | Worker: 10
# Episode: 733 | Moving Average Reward: 114.38 | Episode Reward: 220.20 | True Reward: 41.00 |Loss: 0.015 | Steps: 1792 | Worker: 2
# Episode: 734 | Moving Average Reward: 115.05 | Episode Reward: 181.90 | True Reward: 33.00 |Loss: 0.012 | Steps: 1489 | Worker: 7
# Episode: 735 | Moving Average Reward: 117.96 | Episode Reward: 406.10 | True Reward: 80.00 |Loss: 0.011 | Steps: 3261 | Worker: 9
# Episode: 736 | Moving Average Reward: 116.89 | Episode Reward: 10.30 | True Reward: -3.00 |Loss: 0.073 | Steps: 133 | Worker: 10
# Episode: 737 | Moving Average Reward: 116.59 | Episode Reward: 86.90 | True Reward: 13.00 |Loss: 0.026 | Steps: 739 | Worker: 11
# Episode: 738 | Moving Average Reward: 116.38 | Episode Reward: 96.10 | True Reward: 15.00 |Loss: 0.018 | Steps: 811 | Worker: 6
# Episode: 739 | Moving Average Reward: 115.99 | Episode Reward: 77.20 | True Reward: 11.00 |Loss: 0.031 | Steps: 662 | Worker: 1
# Episode: 740 | Moving Average Reward: 116.32 | Episode Reward: 148.70 | True Reward: 26.00 |Loss: 0.017 | Steps: 1227 | Worker: 4
# Episode: 741 | Moving Average Reward: 115.64 | Episode Reward: 48.60 | True Reward: 5.00 |Loss: 0.033 | Steps: 436 | Worker: 4
# Episode: 742 | Moving Average Reward: 115.97 | Episode Reward: 148.70 | True Reward: 26.00 |Loss: 0.03 | Steps: 1227 | Worker: 10
# Episode: 743 | Moving Average Reward: 116.15 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.02 | Steps: 1114 | Worker: 11
# Episode: 744 | Moving Average Reward: 115.19 | Episode Reward: 20.00 | True Reward: -1.00 |Loss: 0.096 | Steps: 210 | Worker: 10
# Episode: 745 | Moving Average Reward: 115.38 | Episode Reward: 134.40 | True Reward: 23.00 |Loss: 0.016 | Steps: 1114 | Worker: 6

# %%
master.play()
# Out:
# Loading model from: ./gap_change\model_FlappyBird.h5
# 0. Reward: 0.0, action: 1, policy: [[0.2617155 0.7382845]]
# 1. Reward: 0.0, action: 1, policy: [[9.8399166e-04 9.9901605e-01]]
# 2. Reward: 0.0, action: 1, policy: [[4.8766920e-05 9.9995124e-01]]
# 3. Reward: 0.0, action: 1, policy: [[5.2329101e-06 9.9999475e-01]]
# 4. Reward: 0.0, action: 1, policy: [[7.8613448e-07 9.9999917e-01]]
# 5. Reward: 0.0, action: 1, policy: [[2.4033176e-07 9.9999976e-01]]
# 6. Reward: 0.0, action: 1, policy: [[1.1927051e-07 9.9999988e-01]]
# 7. Reward: 0.0, action: 1, policy: [[8.421681e-08 9.999999e-01]]
# 8. Reward: 0.0, action: 1, policy: [[8.507020e-08 9.999999e-01]]
# 9. Reward: 0.0, action: 1, policy: [[1.193069e-07 9.999999e-01]]
# 10. Reward: 0.0, action: 1, policy: [[2.4724193e-07 9.9999976e-01]]
# 11. Reward: 0.0, action: 1, policy: [[7.5164155e-07 9.9999928e-01]]
# 12. Reward: 0.0, action: 1, policy: [[3.1786888e-06 9.9999678e-01]]
# 13. Reward: 0.0, action: 1, policy: [[1.9119836e-05 9.9998093e-01]]
# 14. Reward: 0.0, action: 1, policy: [[1.6421708e-04 9.9983573e-01]]
# 15. Reward: 0.0, action: 1, policy: [[0.0030071  0.99699295]]
# 16. Reward: 0.0, action: 1, policy: [[0.08312982 0.9168701 ]]
# 17. Reward: 0.0, action: 0, policy: [[0.85106725 0.14893275]]
# 18. Reward: 0.0, action: 1, policy: [[0.00102639 0.9989736 ]]
# 19. Reward: 0.0, action: 1, policy: [[4.942368e-05 9.999505e-01]]
# 20. Reward: 0.0, action: 1, policy: [[5.9384652e-06 9.9999404e-01]]
# 21. Reward: 0.0, action: 1, policy: [[9.1653891e-07 9.9999905e-01]]
# 22. Reward: 0.0, action: 1, policy: [[2.0627441e-07 9.9999976e-01]]
# 23. Reward: 0.0, action: 1, policy: [[7.629368e-08 9.999999e-01]]
# 24. Reward: 0.0, action: 1, policy: [[4.3108354e-08 1.0000000e+00]]
# 25. Reward: 0.0, action: 1, policy: [[3.1247502e-08 1.0000000e+00]]
# 26. Reward: 0.0, action: 1, policy: [[3.7494072e-08 1.0000000e+00]]
# 27. Reward: 0.0, action: 1, policy: [[7.447347e-08 9.999999e-01]]
# 28. Reward: 0.0, action: 1, policy: [[2.3953274e-07 9.9999976e-01]]
# 29. Reward: 0.0, action: 1, policy: [[1.0595919e-06 9.9999893e-01]]
# 30. Reward: 0.0, action: 1, policy: [[6.786050e-06 9.999932e-01]]
# 31. Reward: 0.0, action: 1, policy: [[7.3221665e-05 9.9992681e-01]]
# 32. Reward: 0.0, action: 1, policy: [[0.00176196 0.9982381 ]]
# 33. Reward: 0.0, action: 1, policy: [[0.05678263 0.94321734]]
# 34. Reward: 0.0, action: 0, policy: [[0.7840156 0.2159844]]
# 35. Reward: 0.0, action: 1, policy: [[9.282672e-04 9.990717e-01]]
# 36. Reward: 0.0, action: 1, policy: [[2.9973104e-05 9.9997008e-01]]
# 37. Reward: 0.0, action: 1, policy: [[1.8995293e-06 9.9999809e-01]]
# 38. Reward: 0.0, action: 1, policy: [[1.4135951e-07 9.9999988e-01]]
# 39. Reward: 0.0, action: 1, policy: [[1.5342522e-08 1.0000000e+00]]
# 40. Reward: 0.0, action: 1, policy: [[2.8437166e-09 1.0000000e+00]]
# 41. Reward: 0.0, action: 1, policy: [[1.023815e-09 1.000000e+00]]
# 42. Reward: 0.0, action: 1, policy: [[6.694957e-10 1.000000e+00]]
# 43. Reward: 0.0, action: 1, policy: [[7.651205e-10 1.000000e+00]]
# 44. Reward: 0.0, action: 1, policy: [[1.4349758e-09 1.0000000e+00]]
# 45. Reward: 0.0, action: 1, policy: [[4.2857304e-09 1.0000000e+00]]
# 46. Reward: 0.0, action: 1, policy: [[2.41069e-08 1.00000e+00]]
# 47. Reward: 0.0, action: 1, policy: [[2.5574889e-07 9.9999976e-01]]
# 48. Reward: 0.0, action: 1, policy: [[5.8976721e-06 9.9999416e-01]]
# 49. Reward: 0.0, action: 1, policy: [[2.5146763e-04 9.9974853e-01]]
# 50. Reward: 0.0, action: 1, policy: [[0.02162784 0.97837216]]
# 51. Reward: 0.0, action: 0, policy: [[0.76156306 0.23843691]]
# 52. Reward: 0.0, action: 1, policy: [[1.6264999e-04 9.9983728e-01]]
# 53. Reward: 0.0, action: 1, policy: [[2.0940299e-06 9.9999785e-01]]
# 54. Reward: 0.0, action: 1, policy: [[6.011521e-08 9.999999e-01]]
# 55. Reward: 0.0, action: 1, policy: [[1.949311e-09 1.000000e+00]]
# 56. Reward: 0.0, action: 1, policy: [[1.2046629e-10 1.0000000e+00]]
# 57. Reward: 0.0, action: 1, policy: [[1.4241687e-11 1.0000000e+00]]
# 58. Reward: 0.0, action: 1, policy: [[2.988752e-12 1.000000e+00]]
# 59. Reward: 0.0, action: 1, policy: [[1.1938607e-12 1.0000000e+00]]
# 60. Reward: 0.0, action: 1, policy: [[9.272595e-13 1.000000e+00]]
# 61. Reward: 0.0, action: 1, policy: [[1.4442518e-12 1.0000000e+00]]
# 62. Reward: 0.0, action: 1, policy: [[4.3743884e-12 1.0000000e+00]]
# 63. Reward: 0.0, action: 1, policy: [[2.490414e-11 1.000000e+00]]
# 64. Reward: 0.0, action: 1, policy: [[2.5083782e-10 1.0000000e+00]]
# 65. Reward: 1.0, action: 1, policy: [[7.3745765e-09 1.0000000e+00]]
# 66. Reward: 1.0, action: 1, policy: [[3.7374912e-07 9.9999964e-01]]
# 67. Reward: 1.0, action: 1, policy: [[3.7340295e-05 9.9996269e-01]]
# 68. Reward: 1.0, action: 1, policy: [[0.00515076 0.99484926]]
# 69. Reward: 1.0, action: 0, policy: [[0.5570908 0.4429092]]
# 70. Reward: 1.0, action: 1, policy: [[2.2834049e-05 9.9997711e-01]]
# 71. Reward: 1.0, action: 1, policy: [[1.11379904e-07 9.99999881e-01]]
# 72. Reward: 1.0, action: 1, policy: [[1.6049831e-09 1.0000000e+00]]
# 73. Reward: 1.0, action: 1, policy: [[6.830255e-11 1.000000e+00]]
# 74. Reward: 1.0, action: 1, policy: [[3.871674e-12 1.000000e+00]]
# 75. Reward: 1.0, action: 1, policy: [[7.465861e-13 1.000000e+00]]
# 76. Reward: 1.0, action: 1, policy: [[2.472884e-13 1.000000e+00]]
# 77. Reward: 1.0, action: 1, policy: [[1.4846978e-13 1.0000000e+00]]
# 78. Reward: 1.0, action: 1, policy: [[2.7733383e-19 1.0000000e+00]]
# 79. Reward: 1.0, action: 1, policy: [[3.9379515e-19 1.0000000e+00]]
# 80. Reward: 1.0, action: 1, policy: [[9.798901e-19 1.000000e+00]]
# 81. Reward: 1.0, action: 1, policy: [[4.428894e-18 1.000000e+00]]
# 82. Reward: 1.0, action: 1, policy: [[3.6040617e-17 1.0000000e+00]]
# 83. Reward: 1.0, action: 1, policy: [[5.1902473e-16 1.0000000e+00]]
# 84. Reward: 1.0, action: 1, policy: [[1.3730706e-14 1.0000000e+00]]
# 85. Reward: 1.0, action: 1, policy: [[1.2615286e-12 1.0000000e+00]]
# 86. Reward: 1.0, action: 1, policy: [[1.1500873e-10 1.0000000e+00]]
# 87. Reward: 1.0, action: 1, policy: [[2.9487532e-08 1.0000000e+00]]
# 88. Reward: 1.0, action: 1, policy: [[1.9702611e-05 9.9998033e-01]]
# 89. Reward: 1.0, action: 1, policy: [[0.01965735 0.9803427 ]]
# 90. Reward: 1.0, action: 0, policy: [[0.9003165  0.09968346]]
# 91. Reward: 1.0, action: 1, policy: [[1.18855736e-04 9.99881148e-01]]
# 92. Reward: 1.0, action: 1, policy: [[2.021483e-06 9.999980e-01]]
# 93. Reward: 1.0, action: 1, policy: [[5.493467e-08 1.000000e+00]]
# 94. Reward: 1.0, action: 1, policy: [[1.2307382e-09 1.0000000e+00]]
# 95. Reward: 1.0, action: 1, policy: [[6.7748404e-11 1.0000000e+00]]
# 96. Reward: 1.0, action: 1, policy: [[8.77619e-12 1.00000e+00]]
# 97. Reward: 1.0, action: 1, policy: [[1.9510487e-12 1.0000000e+00]]
# 98. Reward: 1.0, action: 1, policy: [[9.112467e-13 1.000000e+00]]
# 99. Reward: 1.0, action: 1, policy: [[7.645956e-13 1.000000e+00]]
# 100. Reward: 1.0, action: 1, policy: [[1.1039174e-12 1.0000000e+00]]
# 101. Reward: 2.0, action: 1, policy: [[2.899534e-12 1.000000e+00]]
# 102. Reward: 2.0, action: 1, policy: [[1.3851938e-11 1.0000000e+00]]
# 103. Reward: 2.0, action: 1, policy: [[1.2180473e-10 1.0000000e+00]]
# 104. Reward: 2.0, action: 1, policy: [[2.0965572e-09 1.0000000e+00]]
# 105. Reward: 2.0, action: 1, policy: [[8.9561325e-08 9.9999988e-01]]
# 106. Reward: 2.0, action: 1, policy: [[5.7852340e-06 9.9999416e-01]]
# 107. Reward: 2.0, action: 1, policy: [[5.302974e-04 9.994697e-01]]
# 108. Reward: 2.0, action: 1, policy: [[0.11417142 0.88582855]]
# 109. Reward: 2.0, action: 0, policy: [[0.9822595  0.01774046]]
# 110. Reward: 2.0, action: 1, policy: [[9.128281e-04 9.990872e-01]]
# 111. Reward: 2.0, action: 1, policy: [[7.452941e-06 9.999925e-01]]
# 112. Reward: 2.0, action: 1, policy: [[1.9113376e-07 9.9999976e-01]]
# 113. Reward: 2.0, action: 1, policy: [[1.783978e-08 1.000000e+00]]
# 114. Reward: 2.0, action: 1, policy: [[1.5686177e-16 1.0000000e+00]]
# 115. Reward: 2.0, action: 1, policy: [[2.2461686e-17 1.0000000e+00]]
# 116. Reward: 2.0, action: 1, policy: [[6.492365e-18 1.000000e+00]]
# 117. Reward: 2.0, action: 1, policy: [[3.4880085e-18 1.0000000e+00]]
# 118. Reward: 2.0, action: 1, policy: [[2.671076e-18 1.000000e+00]]
# 119. Reward: 2.0, action: 1, policy: [[3.4457414e-18 1.0000000e+00]]
# 120. Reward: 2.0, action: 1, policy: [[8.158391e-18 1.000000e+00]]
# 121. Reward: 2.0, action: 1, policy: [[4.6311685e-17 1.0000000e+00]]
# 122. Reward: 2.0, action: 1, policy: [[5.290678e-16 1.000000e+00]]
# 123. Reward: 2.0, action: 1, policy: [[1.211377e-14 1.000000e+00]]
# 124. Reward: 2.0, action: 1, policy: [[4.5081335e-13 1.0000000e+00]]
# 125. Reward: 2.0, action: 1, policy: [[3.466545e-11 1.000000e+00]]
# 126. Reward: 2.0, action: 1, policy: [[5.618849e-09 1.000000e+00]]
# 127. Reward: 2.0, action: 1, policy: [[2.1302176e-06 9.9999785e-01]]
# 128. Reward: 2.0, action: 1, policy: [[9.9000789e-04 9.9900997e-01]]
# 129. Reward: 2.0, action: 1, policy: [[0.30153716 0.69846284]]
# 130. Reward: 2.0, action: 0, policy: [[0.99279743 0.00720264]]
# 131. Reward: 2.0, action: 1, policy: [[0.00196204 0.998038  ]]
# 132. Reward: 2.0, action: 1, policy: [[3.8495513e-05 9.9996150e-01]]
# 133. Reward: 2.0, action: 1, policy: [[1.7525774e-06 9.9999821e-01]]
# 134. Reward: 2.0, action: 1, policy: [[5.5313176e-08 1.0000000e+00]]
# 135. Reward: 2.0, action: 1, policy: [[1.8711366e-09 1.0000000e+00]]
# 136. Reward: 2.0, action: 1, policy: [[1.3487494e-10 1.0000000e+00]]
# 137. Reward: 3.0, action: 1, policy: [[2.0568354e-11 1.0000000e+00]]
# 138. Reward: 3.0, action: 1, policy: [[6.841791e-12 1.000000e+00]]
# 139. Reward: 3.0, action: 1, policy: [[4.5882213e-12 1.0000000e+00]]
# 140. Reward: 3.0, action: 1, policy: [[6.8382036e-12 1.0000000e+00]]
# 141. Reward: 3.0, action: 1, policy: [[2.0068681e-11 1.0000000e+00]]
# 142. Reward: 3.0, action: 1, policy: [[1.1895364e-10 1.0000000e+00]]
# 143. Reward: 3.0, action: 1, policy: [[1.4260538e-09 1.0000000e+00]]
# 144. Reward: 3.0, action: 1, policy: [[3.489789e-08 1.000000e+00]]
# 145. Reward: 3.0, action: 1, policy: [[1.4284467e-06 9.9999857e-01]]
# 146. Reward: 3.0, action: 1, policy: [[7.5673415e-05 9.9992430e-01]]
# 147. Reward: 3.0, action: 1, policy: [[0.00991241 0.99008757]]
# 148. Reward: 3.0, action: 0, policy: [[0.6526443  0.34735566]]
# 149. Reward: 3.0, action: 1, policy: [[6.4100641e-05 9.9993587e-01]]
# 150. Reward: 3.0, action: 1, policy: [[1.910247e-14 1.000000e+00]]
# 151. Reward: 3.0, action: 1, policy: [[1.1926003e-15 1.0000000e+00]]
# 152. Reward: 3.0, action: 1, policy: [[1.069378e-16 1.000000e+00]]
# 153. Reward: 3.0, action: 1, policy: [[1.898222e-17 1.000000e+00]]
# 154. Reward: 3.0, action: 1, policy: [[6.2212022e-18 1.0000000e+00]]
# 155. Reward: 3.0, action: 1, policy: [[3.2519377e-18 1.0000000e+00]]
# 156. Reward: 3.0, action: 1, policy: [[2.5939666e-18 1.0000000e+00]]
# 157. Reward: 3.0, action: 1, policy: [[3.055694e-18 1.000000e+00]]
# 158. Reward: 3.0, action: 1, policy: [[5.3419403e-18 1.0000000e+00]]
# 159. Reward: 3.0, action: 1, policy: [[1.4011409e-17 1.0000000e+00]]
# 160. Reward: 3.0, action: 1, policy: [[6.021547e-17 1.000000e+00]]
# 161. Reward: 3.0, action: 1, policy: [[4.1109643e-16 1.0000000e+00]]
# 162. Reward: 3.0, action: 1, policy: [[5.3542096e-15 1.0000000e+00]]
# 163. Reward: 3.0, action: 1, policy: [[1.4526303e-13 1.0000000e+00]]
# 164. Reward: 3.0, action: 1, policy: [[8.9988555e-12 1.0000000e+00]]
# 165. Reward: 3.0, action: 1, policy: [[6.77951e-10 1.00000e+00]]
# 166. Reward: 3.0, action: 1, policy: [[8.942750e-08 9.999999e-01]]
# 167. Reward: 3.0, action: 1, policy: [[2.7128144e-05 9.9997282e-01]]
# 168. Reward: 3.0, action: 1, policy: [[0.01238607 0.9876139 ]]
# 169. Reward: 3.0, action: 0, policy: [[0.7922521  0.20774789]]
# 170. Reward: 3.0, action: 1, policy: [[1.0863762e-04 9.9989140e-01]]
# 171. Reward: 3.0, action: 1, policy: [[2.1960948e-06 9.9999785e-01]]
# 172. Reward: 3.0, action: 1, policy: [[9.766712e-08 9.999999e-01]]
# 173. Reward: 3.0, action: 1, policy: [[7.3168795e-09 1.0000000e+00]]
# 174. Reward: 3.0, action: 1, policy: [[1.0182278e-09 1.0000000e+00]]
# 175. Reward: 3.0, action: 1, policy: [[2.2369502e-10 1.0000000e+00]]
# 176. Reward: 3.0, action: 1, policy: [[7.7454224e-11 1.0000000e+00]]
# 177. Reward: 3.0, action: 1, policy: [[4.830442e-11 1.000000e+00]]
# 178. Reward: 4.0, action: 1, policy: [[5.547453e-11 1.000000e+00]]
# 179. Reward: 4.0, action: 1, policy: [[1.1684727e-10 1.0000000e+00]]
# t:   0%|                                                                                                           | 0/211 [00:00<?, ?it/s, now=None]
# 180. Reward: 4.0, action: 1, policy: [[4.1576667e-10 1.0000000e+00]]
# 181. Reward: 4.0, action: 1, policy: [[2.5928755e-09 1.0000000e+00]]
# 182. Reward: 4.0, action: 1, policy: [[2.5791993e-08 1.0000000e+00]]
# 183. Reward: 4.0, action: 1, policy: [[4.3399334e-07 9.9999952e-01]]
# 184. Reward: 4.0, action: 1, policy: [[1.2071287e-05 9.9998796e-01]]
# 185. Reward: 4.0, action: 1, policy: [[7.1673765e-04 9.9928325e-01]]
# 186. Reward: 4.0, action: 1, policy: [[0.06227109 0.93772894]]
# 187. Reward: 4.0, action: 0, policy: [[0.91623324 0.08376674]]
# 188. Reward: 4.0, action: 1, policy: [[1.8261142e-04 9.9981743e-01]]
# 189. Reward: 4.0, action: 1, policy: [[2.5057373e-06 9.9999750e-01]]
# 190. Reward: 4.0, action: 1, policy: [[1.0045767e-07 9.9999988e-01]]
# 191. Reward: 4.0, action: 0, policy: [[1.000000e+00 9.242429e-22]]
# 192. Reward: 4.0, action: 0, policy: [[1.0000000e+00 9.2636874e-20]]
# 193. Reward: 4.0, action: 0, policy: [[1.0000000e+00 6.0330313e-21]]
# 194. Reward: 4.0, action: 0, policy: [[1.0000000e+00 4.8429704e-18]]
# 195. Reward: 4.0, action: 0, policy: [[1.0000000e+00 3.0567648e-19]]
# 196. Reward: 4.0, action: 0, policy: [[1.0000000e+00 2.5916649e-16]]
# 197. Reward: 4.0, action: 0, policy: [[1.0000000e+00 1.5529878e-17]]
# 198. Reward: 4.0, action: 0, policy: [[1.0000000e+00 1.3894917e-14]]
# 199. Reward: 4.0, action: 0, policy: [[1.000000e+00 8.170391e-16]]
# 200. Reward: 4.0, action: 0, policy: [[1.000000e+00 7.502676e-13]]
# 201. Reward: 4.0, action: 0, policy: [[1.000000e+00 4.319555e-14]]
# 202. Reward: 4.0, action: 0, policy: [[1.0000000e+00 2.7849585e-11]]
# 203. Reward: 4.0, action: 0, policy: [[1.0000000e+00 1.8052959e-12]]
# 204. Reward: 4.0, action: 0, policy: [[1.0000000e+00 1.0479182e-09]]
# 205. Reward: 4.0, action: 0, policy: [[1.0000000e+00 5.1957088e-11]]
# 206. Reward: 4.0, action: 0, policy: [[1.000000e+00 4.372479e-08]]
# 207. Reward: 4.0, action: 0, policy: [[1.000000e+00 2.391778e-09]]
# 208. Reward: 4.0, action: 0, policy: [[9.9999702e-01 3.0154035e-06]]
# 209. Reward: 4.0, action: 0, policy: [[9.9999976e-01 2.3798599e-07]]
# 210. Reward: -1.0, action: 0, policy: [[9.9963915e-01 3.6089355e-04]]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
from IPython.display import Image, display

reward_per_epoch = []
lifetime_per_epoch = []
exploring_rates = []
learning_rates = []
print_every_episode = 500
show_gif_every_episode = 5000
NUM_EPISODE = 40000
for episode in range(0, NUM_EPISODE):

    # Reset the environment
    env.reset_game()

    # record frame
    frames = [env.getScreenRGB()]

    # for every 500 episodes, shutdown exploration to see performance of greedy action
    if episode % print_every_episode == 0:
        agent.shutdown_explore()

    # the initial state
    state = game.getGameState()
    action = agent.select_action(state)
    # cumulate reward for this episode
    cum_reward = 0  
    t = 0

    while not env.game_over():

        # execute the action and get reward
        # reward = +1 when pass a pipe, -5 when die
        reward = env.act(env.getActionSet()[action])  

        frames.append(env.getScreenRGB())

        # cumulate reward
        cum_reward += reward

        # observe the result
        state_prime = game.getGameState()  # get next state
        action_prime = agent.select_action(state_prime)

        # update agent
        agent.update_policy(state, action, reward, state_prime, action_prime)

        # Setting up for the next iteration
        action = action_prime
        state = state_prime
        t += 1

    # update exploring_rate and learning_rate
    agent.update_parameters(episode)

    if episode % print_every_episode == 0:
        print("Episode {} finished after {} time steps, cumulated reward: {}, exploring rate: {}, learning rate: {}".format(
            episode,
            t,
            cum_reward,
            agent.exploring_rate,
            agent.learning_rate
        ))
        reward_per_epoch.append(cum_reward)
        exploring_rates.append(agent.exploring_rate)
        learning_rates.append(agent.learning_rate)
        lifetime_per_epoch.append(t)

    # for every 5000 episode, record an animation
    if episode % show_gif_every_episode == 0:
        print("len frames:", len(frames))
        clip = make_anim(frames, fps=60, true_image=True).rotate(-90)
        display(clip.ipython_display(fps=60, autoplay=1, loop=1))
